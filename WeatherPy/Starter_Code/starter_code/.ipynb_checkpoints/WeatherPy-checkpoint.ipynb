# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
import scipy.stats as st
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 611

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_name = []
city_data = []
city_lat = []
city_lon = []
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&APPID={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_name.append(response["name"])
        city_lat.append(response["coord"]["lat"])
        city_lon.append(response["coord"]["lon"])
        city_max_temp.append(response["main"]["temp_max"])
        city_humidity.append(response["main"]["humidity"])
        city_clouds.append(response["clouds"]["all"])
        city_wind.append(response["wind"]["speed"])
        city_country.append(response["sys"]["country"])
        city_date.append(response["dt"])

        # Append the City information into city_data list
        city_data.append({"City": city_name, 
                          "Lat": city_lat, 
                          "Lng": city_lon, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

print(response)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 2 of Set 1 | kerikeri
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | sukumo
# Processing Record 5 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | hasaki
# Processing Record 8 of Set 1 | papatowai
# Processing Record 9 of Set 1 | stanley
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | jiangyou
# Processing Record 12 of Set 1 | college
# Processing Record 13 of Set 1 | grytviken
# Processing Record 14 of Set 1 | kavaratti
# Processing Record 15 of Set 1 | malvan
# Processing Record 16 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 17 of Set 1 | avsallar
# Processing Record 18 of Set 1 | sibolga
# Processing Record 19 of Set 1 | edinburgh of the seven seas
# Processing Record 20 of Set 1 | ta`u
# Processing Record 21 of Set 1 | waitangi
# Processing Record 22 of Set 1 | blackmans bay
# Processing Record 23 of Set 1 | hawaiian paradise park
# Processing Record 24 of Set 1 | atafu village
# Processing Record 25 of Set 1 | sheksna
# Processing Record 26 of Set 1 | west island
# Processing Record 27 of Set 1 | codrington
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | freetown
# Processing Record 30 of Set 1 | wailua homesteads
# Processing Record 31 of Set 1 | acarau
# Processing Record 32 of Set 1 | hammerfest
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | mogadishu
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | recke
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | igarka
# Processing Record 40 of Set 1 | lompoc
# Processing Record 41 of Set 1 | constantia
# Processing Record 42 of Set 1 | dhidhdhoo
# Processing Record 43 of Set 1 | adamstown
# Processing Record 44 of Set 1 | lata
# Processing Record 45 of Set 1 | longquan
# Processing Record 46 of Set 1 | puerto natales
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | champerico
# Processing Record 50 of Set 1 | zinjibar
# Processing Record 0 of Set 2 | masterton
# Processing Record 1 of Set 2 | port mathurin
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | tapes
# Processing Record 4 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 5 of Set 2 | pakruojis
# Processing Record 6 of Set 2 | dalandzadgad
# Processing Record 7 of Set 2 | itaituba
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | keflavik
# Processing Record 10 of Set 2 | guerrero negro
# Processing Record 11 of Set 2 | happy valley-goose bay
# Processing Record 12 of Set 2 | barbastro
# Processing Record 13 of Set 2 | vila velha
# Processing Record 14 of Set 2 | ola
# Processing Record 15 of Set 2 | kuraymah
# Processing Record 16 of Set 2 | tiksi
# Processing Record 17 of Set 2 | la union
# Processing Record 18 of Set 2 | okhotsk
# Processing Record 19 of Set 2 | bonthe
# Processing Record 20 of Set 2 | broome
# Processing Record 21 of Set 2 | tanout
# Processing Record 22 of Set 2 | pires do rio
# Processing Record 23 of Set 2 | trujillo
# Processing Record 24 of Set 2 | tobi village
# City not found. Skipping...
# Processing Record 25 of Set 2 | yashkul'
# Processing Record 26 of Set 2 | olonkinbyen
# Processing Record 27 of Set 2 | margaret river
# Processing Record 28 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 29 of Set 2 | grand baie
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | jiexiu
# Processing Record 32 of Set 2 | mongo
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | paranaiba
# Processing Record 35 of Set 2 | pacific grove
# Processing Record 36 of Set 2 | benguela
# Processing Record 37 of Set 2 | port macquarie
# Processing Record 38 of Set 2 | laguna
# Processing Record 39 of Set 2 | georgetown
# Processing Record 40 of Set 2 | tazacorte
# Processing Record 41 of Set 2 | bhongir
# Processing Record 42 of Set 2 | sankt veit an der glan
# Processing Record 43 of Set 2 | san luis de la loma
# Processing Record 44 of Set 2 | sinabang
# Processing Record 45 of Set 2 | grand falls-windsor
# Processing Record 46 of Set 2 | san julian
# Processing Record 47 of Set 2 | santa cruz
# Processing Record 48 of Set 2 | cubuk
# Processing Record 49 of Set 2 | hamilton
# Processing Record 0 of Set 3 | richards bay
# Processing Record 1 of Set 3 | hami
# Processing Record 2 of Set 3 | rauma
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | remire-montjoly
# Processing Record 5 of Set 3 | pandan
# Processing Record 6 of Set 3 | kingston
# Processing Record 7 of Set 3 | ungsang-nodongjagu
# Processing Record 8 of Set 3 | dakhla
# Processing Record 9 of Set 3 | vorgashor
# Processing Record 10 of Set 3 | coquimbo
# Processing Record 11 of Set 3 | lihue
# Processing Record 12 of Set 3 | novosergiyevka
# Processing Record 13 of Set 3 | gaspe
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | klyuchi
# Processing Record 16 of Set 3 | khalkhal
# Processing Record 17 of Set 3 | longonjo
# Processing Record 18 of Set 3 | whitehorse
# Processing Record 19 of Set 3 | bria
# Processing Record 20 of Set 3 | porto novo
# Processing Record 21 of Set 3 | avon
# Processing Record 22 of Set 3 | colonia
# Processing Record 23 of Set 3 | macapa
# Processing Record 24 of Set 3 | novodvinsk
# Processing Record 25 of Set 3 | albany
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | mineros
# Processing Record 28 of Set 3 | puerto baquerizo moreno
# Processing Record 29 of Set 3 | canutama
# Processing Record 30 of Set 3 | bada
# Processing Record 31 of Set 3 | sitka
# Processing Record 32 of Set 3 | punta arenas
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | newman
# Processing Record 36 of Set 3 | rio grande
# Processing Record 37 of Set 3 | khuzdar
# Processing Record 38 of Set 3 | ancud
# Processing Record 39 of Set 3 | alo
# Processing Record 40 of Set 3 | conde
# Processing Record 41 of Set 3 | bredasdorp
# Processing Record 42 of Set 3 | alofi
# Processing Record 43 of Set 3 | isafjordur
# Processing Record 44 of Set 3 | seogwipo
# City not found. Skipping...
# Processing Record 45 of Set 3 | tynda
# Processing Record 46 of Set 3 | jamaame
# Processing Record 47 of Set 3 | gebeit
# Processing Record 48 of Set 3 | formosa do rio preto
# Processing Record 49 of Set 3 | dudinka
# Processing Record 0 of Set 4 | bahia de caraquez
# Processing Record 1 of Set 4 | kirensk
# Processing Record 2 of Set 4 | ocean pointe
# City not found. Skipping...
# Processing Record 3 of Set 4 | saint-pierre
# Processing Record 4 of Set 4 | loango
# Processing Record 5 of Set 4 | malango
# Processing Record 6 of Set 4 | saipan
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | gadzhiyevo
# Processing Record 9 of Set 4 | hadibu
# Processing Record 10 of Set 4 | jamestown
# Processing Record 11 of Set 4 | sisimiut
# Processing Record 12 of Set 4 | auki
# Processing Record 13 of Set 4 | adi keyh
# Processing Record 14 of Set 4 | fort-shevchenko
# Processing Record 15 of Set 4 | vilyuchinsk
# Processing Record 16 of Set 4 | sumberpucung
# Processing Record 17 of Set 4 | praia da vitoria
# Processing Record 18 of Set 4 | arteche
# Processing Record 19 of Set 4 | san andres
# Processing Record 20 of Set 4 | ligny-en-barrois
# Processing Record 21 of Set 4 | luderitz
# Processing Record 22 of Set 4 | korsor
# Processing Record 23 of Set 4 | afaahiti
# Processing Record 24 of Set 4 | badger
# Processing Record 25 of Set 4 | tolanaro
# Processing Record 26 of Set 4 | chonchi
# Processing Record 27 of Set 4 | marcala
# Processing Record 28 of Set 4 | whakatane
# Processing Record 29 of Set 4 | gisborne
# Processing Record 30 of Set 4 | axim
# Processing Record 31 of Set 4 | villa del totoral
# Processing Record 32 of Set 4 | keminmaa
# Processing Record 33 of Set 4 | hermantown
# Processing Record 34 of Set 4 | lashio
# Processing Record 35 of Set 4 | walvis bay
# Processing Record 36 of Set 4 | enewetak
# Processing Record 37 of Set 4 | pangkalpinang
# Processing Record 38 of Set 4 | sao francisco
# Processing Record 39 of Set 4 | skovorodino
# Processing Record 40 of Set 4 | tabas
# Processing Record 41 of Set 4 | sergach
# Processing Record 42 of Set 4 | port lincoln
# Processing Record 43 of Set 4 | kendari
# Processing Record 44 of Set 4 | pasni
# Processing Record 45 of Set 4 | esmeralda
# Processing Record 46 of Set 4 | alvaraes
# Processing Record 47 of Set 4 | gaoping
# Processing Record 48 of Set 4 | aykhal
# Processing Record 49 of Set 4 | griffith
# Processing Record 0 of Set 5 | invercargill
# Processing Record 1 of Set 5 | bandundu
# Processing Record 2 of Set 5 | qaqortoq
# Processing Record 3 of Set 5 | balotra
# Processing Record 4 of Set 5 | lebu
# Processing Record 5 of Set 5 | kapuskasing
# Processing Record 6 of Set 5 | haiku-pauwela
# Processing Record 7 of Set 5 | utrik
# Processing Record 8 of Set 5 | roswell
# Processing Record 9 of Set 5 | zhigalovo
# Processing Record 10 of Set 5 | botshabelo
# Processing Record 11 of Set 5 | soto la marina
# Processing Record 12 of Set 5 | zhangye
# Processing Record 13 of Set 5 | zaozersk
# Processing Record 14 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 15 of Set 5 | vohipaho
# City not found. Skipping...
# Processing Record 16 of Set 5 | flying fish cove
# Processing Record 17 of Set 5 | westport
# Processing Record 18 of Set 5 | undurkhaan
# Processing Record 19 of Set 5 | altay
# Processing Record 20 of Set 5 | perros-guirec
# Processing Record 21 of Set 5 | san pedro pochutla
# Processing Record 22 of Set 5 | duba
# Processing Record 23 of Set 5 | anadyr
# Processing Record 24 of Set 5 | alesund
# Processing Record 25 of Set 5 | enterprise
# Processing Record 26 of Set 5 | priob'ye
# Processing Record 27 of Set 5 | nantucket
# Processing Record 28 of Set 5 | lazaro cardenas
# Processing Record 29 of Set 5 | tazovsky
# Processing Record 30 of Set 5 | inhambane
# Processing Record 31 of Set 5 | conception bay south
# Processing Record 32 of Set 5 | ballina
# Processing Record 33 of Set 5 | arboletes
# Processing Record 34 of Set 5 | nemuro
# Processing Record 35 of Set 5 | callao
# Processing Record 36 of Set 5 | karratha
# Processing Record 37 of Set 5 | laayoune
# Processing Record 38 of Set 5 | vrangel'
# Processing Record 39 of Set 5 | albertina
# Processing Record 40 of Set 5 | shetpe
# Processing Record 41 of Set 5 | iskateley
# Processing Record 42 of Set 5 | leh
# Processing Record 43 of Set 5 | tsengel
# Processing Record 44 of Set 5 | weno
# Processing Record 45 of Set 5 | tutoia
# Processing Record 46 of Set 5 | la passe
# Processing Record 47 of Set 5 | cadale
# Processing Record 48 of Set 5 | ejutla de crespo
# Processing Record 49 of Set 5 | thinadhoo
# Processing Record 0 of Set 6 | kapa'a
# Processing Record 1 of Set 6 | kollam
# Processing Record 2 of Set 6 | papao
# Processing Record 3 of Set 6 | ayod
# City not found. Skipping...
# Processing Record 4 of Set 6 | souillac
# Processing Record 5 of Set 6 | aasiaat
# Processing Record 6 of Set 6 | luis correia
# Processing Record 7 of Set 6 | inarajan village
# Processing Record 8 of Set 6 | santa elena de uairen
# Processing Record 9 of Set 6 | senador jose porfirio
# Processing Record 10 of Set 6 | zouerate
# Processing Record 11 of Set 6 | sussex
# Processing Record 12 of Set 6 | tindouf
# Processing Record 13 of Set 6 | sal rei
# Processing Record 14 of Set 6 | cabras
# Processing Record 15 of Set 6 | mocimboa
# Processing Record 16 of Set 6 | vadso
# Processing Record 17 of Set 6 | trenggalek
# Processing Record 18 of Set 6 | calama
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | bilibino
# Processing Record 21 of Set 6 | yangor
# City not found. Skipping...
# Processing Record 22 of Set 6 | hirara
# Processing Record 23 of Set 6 | imbituba
# Processing Record 24 of Set 6 | port glaud
# City not found. Skipping...
# Processing Record 25 of Set 6 | meulaboh
# Processing Record 26 of Set 6 | fale old settlement
# Processing Record 27 of Set 6 | nar'yan-mar
# Processing Record 28 of Set 6 | ribeira brava
# Processing Record 29 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 30 of Set 6 | belmonte
# Processing Record 31 of Set 6 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 32 of Set 6 | lensk
# Processing Record 33 of Set 6 | leominster
# Processing Record 34 of Set 6 | saint-denis
# Processing Record 35 of Set 6 | akrehamn
# Processing Record 36 of Set 6 | shohimardon
# Processing Record 37 of Set 6 | chegdomyn
# Processing Record 38 of Set 6 | uturoa
# Processing Record 39 of Set 6 | errachidia
# Processing Record 40 of Set 6 | samarinda
# Processing Record 41 of Set 6 | greymouth
# Processing Record 42 of Set 6 | farasan
# Processing Record 43 of Set 6 | semporna
# Processing Record 44 of Set 6 | bomdila
# Processing Record 45 of Set 6 | rangia
# Processing Record 46 of Set 6 | raduzhny
# Processing Record 47 of Set 6 | kimbe
# Processing Record 48 of Set 6 | leava
# Processing Record 49 of Set 6 | broken hill
# Processing Record 0 of Set 7 | darnah
# Processing Record 1 of Set 7 | chibougamau
# Processing Record 2 of Set 7 | popondetta
# Processing Record 3 of Set 7 | svetlyy
# Processing Record 4 of Set 7 | port isabel
# Processing Record 5 of Set 7 | plastun
# Processing Record 6 of Set 7 | magadan
# Processing Record 7 of Set 7 | cabedelo
# Processing Record 8 of Set 7 | ataq
# Processing Record 9 of Set 7 | st. john's
# Processing Record 10 of Set 7 | fonte boa
# Processing Record 11 of Set 7 | ketchikan
# Processing Record 12 of Set 7 | mawlaik
# Processing Record 13 of Set 7 | oistins
# Processing Record 14 of Set 7 | al bawiti
# Processing Record 15 of Set 7 | outapi
# City not found. Skipping...
# Processing Record 16 of Set 7 | arraial do cabo
# Processing Record 17 of Set 7 | nyurba
# Processing Record 18 of Set 7 | minas de marcona
# Processing Record 19 of Set 7 | prado
# Processing Record 20 of Set 7 | carnarvon
# Processing Record 21 of Set 7 | umm kaddadah
# Processing Record 22 of Set 7 | kayangel
# Processing Record 23 of Set 7 | kailua-kona
# Processing Record 24 of Set 7 | macaubas
# Processing Record 25 of Set 7 | kievka
# Processing Record 26 of Set 7 | port-vila
# Processing Record 27 of Set 7 | lincoln
# Processing Record 28 of Set 7 | aitape
# Processing Record 29 of Set 7 | alice springs
# Processing Record 30 of Set 7 | namibe
# Processing Record 31 of Set 7 | san pedro
# Processing Record 32 of Set 7 | maloye ganyushkino
# Processing Record 33 of Set 7 | mana
# Processing Record 34 of Set 7 | noginsk
# Processing Record 35 of Set 7 | paradera
# City not found. Skipping...
# Processing Record 36 of Set 7 | grafton
# Processing Record 37 of Set 7 | graaff-reinet
# Processing Record 38 of Set 7 | san patricio
# Processing Record 39 of Set 7 | usogorsk
# Processing Record 40 of Set 7 | severo-yeniseyskiy
# Processing Record 41 of Set 7 | murun-kuren
# Processing Record 42 of Set 7 | puerto aysen
# Processing Record 43 of Set 7 | akureyri
# Processing Record 44 of Set 7 | aswan
# Processing Record 45 of Set 7 | puerto deseado
# Processing Record 46 of Set 7 | muzayri'
# City not found. Skipping...
# Processing Record 47 of Set 7 | karukh
# Processing Record 48 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 49 of Set 7 | smithers
# Processing Record 0 of Set 8 | qamdo
# Processing Record 1 of Set 8 | holualoa
# Processing Record 2 of Set 8 | kourou
# Processing Record 3 of Set 8 | khanty-mansiysk
# Processing Record 4 of Set 8 | kyshtovka
# Processing Record 5 of Set 8 | prince rupert
# Processing Record 6 of Set 8 | east london
# Processing Record 7 of Set 8 | mount isa
# Processing Record 8 of Set 8 | tangalle
# Processing Record 9 of Set 8 | priladozhskiy
# Processing Record 10 of Set 8 | polyarnyy
# Processing Record 11 of Set 8 | istgah-e rah ahan-e garmsar
# Processing Record 12 of Set 8 | balabac
# Processing Record 13 of Set 8 | west end village
# City not found. Skipping...
# Processing Record 14 of Set 8 | saint-joseph
# Processing Record 15 of Set 8 | sabang
# Processing Record 16 of Set 8 | dryden
# Processing Record 17 of Set 8 | manado
# Processing Record 18 of Set 8 | tharad
# Processing Record 19 of Set 8 | tuy hoa
# Processing Record 20 of Set 8 | kununurra
# Processing Record 21 of Set 8 | manicore
# Processing Record 22 of Set 8 | ginir
# Processing Record 23 of Set 8 | conil de la frontera
# Processing Record 24 of Set 8 | fada
# Processing Record 25 of Set 8 | kruisfontein
# Processing Record 26 of Set 8 | sinop
# Processing Record 27 of Set 8 | la paz
# Processing Record 28 of Set 8 | ad dabbah
# Processing Record 29 of Set 8 | valdivia
# Processing Record 30 of Set 8 | bad neustadt an der saale
# Processing Record 31 of Set 8 | touros
# Processing Record 32 of Set 8 | al bardiyah
# Processing Record 33 of Set 8 | tenenkou
# Processing Record 34 of Set 8 | waingapu
# Processing Record 35 of Set 8 | beledweyne
# Processing Record 36 of Set 8 | kribi
# Processing Record 37 of Set 8 | santana
# Processing Record 38 of Set 8 | palmer
# Processing Record 39 of Set 8 | valparaiso
# Processing Record 40 of Set 8 | harnai
# Processing Record 41 of Set 8 | namtsy
# Processing Record 42 of Set 8 | arkhangel'sk
# Processing Record 43 of Set 8 | saudarkrokur
# Processing Record 44 of Set 8 | taulaga
# Processing Record 45 of Set 8 | ocean shores
# Processing Record 46 of Set 8 | port douglas
# Processing Record 47 of Set 8 | morehead city
# Processing Record 48 of Set 8 | kuanda
# Processing Record 49 of Set 8 | villa gesell
# Processing Record 0 of Set 9 | salinopolis
# Processing Record 1 of Set 9 | la punta
# Processing Record 2 of Set 9 | tubarjal
# Processing Record 3 of Set 9 | kangding
# Processing Record 4 of Set 9 | guigang
# Processing Record 5 of Set 9 | bompas
# Processing Record 6 of Set 9 | naze
# Processing Record 7 of Set 9 | tobol'sk
# Processing Record 8 of Set 9 | lionel town
# Processing Record 9 of Set 9 | amos
# Processing Record 10 of Set 9 | rapid city
# Processing Record 11 of Set 9 | kuta
# Processing Record 12 of Set 9 | port saint john's
# Processing Record 13 of Set 9 | greenville
# Processing Record 14 of Set 9 | kapoeta
# Processing Record 15 of Set 9 | dondo
# Processing Record 16 of Set 9 | corlette
# Processing Record 17 of Set 9 | upington
# Processing Record 18 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 19 of Set 9 | juhaynah
# Processing Record 20 of Set 9 | sao joao dos inhamuns
# Processing Record 21 of Set 9 | gordonvale
# Processing Record 22 of Set 9 | brookings
# Processing Record 23 of Set 9 | labrador city
# Processing Record 24 of Set 9 | sarangani
# Processing Record 25 of Set 9 | zheleznogorsk
# Processing Record 26 of Set 9 | den burg
# Processing Record 27 of Set 9 | pyin oo lwin
# Processing Record 28 of Set 9 | song cau
# Processing Record 29 of Set 9 | wotho
# Processing Record 30 of Set 9 | outjo
# Processing Record 31 of Set 9 | road town
# Processing Record 32 of Set 9 | azemmour
# Processing Record 33 of Set 9 | saint-philippe
# Processing Record 34 of Set 9 | paita
# Processing Record 35 of Set 9 | faya-largeau
# Processing Record 36 of Set 9 | thanh hoa
# Processing Record 37 of Set 9 | al ghayzah
# Processing Record 38 of Set 9 | konarka
# Processing Record 39 of Set 9 | verdal
# Processing Record 40 of Set 9 | laojunmiao
# Processing Record 41 of Set 9 | metro
# Processing Record 42 of Set 9 | tralee
# Processing Record 43 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 9 | lillehammer
# Processing Record 45 of Set 9 | colon
# Processing Record 46 of Set 9 | watford city
# Processing Record 47 of Set 9 | puerto palomas
# Processing Record 48 of Set 9 | levuka
# Processing Record 49 of Set 9 | manismata
# Processing Record 0 of Set 10 | macau
# Processing Record 1 of Set 10 | nuuk
# Processing Record 2 of Set 10 | rongelap
# Processing Record 3 of Set 10 | coahuayana de hidalgo
# Processing Record 4 of Set 10 | cannonvale
# Processing Record 5 of Set 10 | howrah
# Processing Record 6 of Set 10 | suances
# Processing Record 7 of Set 10 | san miguel de cauri
# Processing Record 8 of Set 10 | stornoway
# Processing Record 9 of Set 10 | copala
# Processing Record 10 of Set 10 | ixtapa
# Processing Record 11 of Set 10 | baiti
# Processing Record 12 of Set 10 | mo i rana
# Processing Record 13 of Set 10 | saksaul'skiy
# City not found. Skipping...
# Processing Record 14 of Set 10 | valdez
# Processing Record 15 of Set 10 | zemio
# Processing Record 16 of Set 10 | veraval
# Processing Record 17 of Set 10 | hamakita
# Processing Record 18 of Set 10 | usinsk
# Processing Record 19 of Set 10 | nova vicosa
# Processing Record 20 of Set 10 | idaho falls
# Processing Record 21 of Set 10 | mata-utu
# Processing Record 22 of Set 10 | novo aripuana
# Processing Record 23 of Set 10 | shingu
# Processing Record 24 of Set 10 | sarkand
# Processing Record 25 of Set 10 | muroto-misakicho
# Processing Record 26 of Set 10 | kistelek
# Processing Record 27 of Set 10 | horta
# Processing Record 28 of Set 10 | genhe
# Processing Record 29 of Set 10 | victoria falls
# Processing Record 30 of Set 10 | kismayo
# Processing Record 31 of Set 10 | kayyerkan
# Processing Record 32 of Set 10 | arawa
# Processing Record 33 of Set 10 | tyup
# Processing Record 34 of Set 10 | pathein
# Processing Record 35 of Set 10 | richfield
# Processing Record 36 of Set 10 | sirte
# Processing Record 37 of Set 10 | hovd
# Processing Record 38 of Set 10 | thunder bay
# Processing Record 39 of Set 10 | ust-nera
# Processing Record 40 of Set 10 | pimentel
# Processing Record 41 of Set 10 | senanga
# Processing Record 42 of Set 10 | mega
# Processing Record 43 of Set 10 | shalqar
# Processing Record 44 of Set 10 | tha khanon
# Processing Record 45 of Set 10 | mitchell
# Processing Record 46 of Set 10 | suntar
# Processing Record 47 of Set 10 | mariinsk
# Processing Record 48 of Set 10 | yatou
# Processing Record 49 of Set 10 | taoudenni
# Processing Record 0 of Set 11 | maintirano
# Processing Record 1 of Set 11 | island harbour
# Processing Record 2 of Set 11 | ovalle
# Processing Record 3 of Set 11 | arkhipo-osipovka
# Processing Record 4 of Set 11 | susuman
# Processing Record 5 of Set 11 | cambria
# Processing Record 6 of Set 11 | kupang
# Processing Record 7 of Set 11 | savave village
# City not found. Skipping...
# Processing Record 8 of Set 11 | mangrol
# Processing Record 9 of Set 11 | paxtakor shahri
# City not found. Skipping...
# Processing Record 10 of Set 11 | dzhalagash
# Processing Record 11 of Set 11 | strezhevoy
# Processing Record 12 of Set 11 | arvayheer
# Processing Record 13 of Set 11 | altai
# Processing Record 14 of Set 11 | kovilpatti
# Processing Record 15 of Set 11 | tsiombe
# Processing Record 16 of Set 11 | paramonga
# Processing Record 17 of Set 11 | hun
# Processing Record 18 of Set 11 | calabozo
# Processing Record 19 of Set 11 | codajas
# Processing Record 20 of Set 11 | pointe-noire
# Processing Record 21 of Set 11 | jaru
# Processing Record 22 of Set 11 | fortuna
# Processing Record 23 of Set 11 | champoton
# Processing Record 24 of Set 11 | wewak
# Processing Record 25 of Set 11 | fortaleza
# Processing Record 26 of Set 11 | nelson
# Processing Record 27 of Set 11 | troy
# Processing Record 28 of Set 11 | mili
# Processing Record 29 of Set 11 | cairns city
# City not found. Skipping...
# Processing Record 30 of Set 11 | zangguy
# City not found. Skipping...
# Processing Record 31 of Set 11 | cole harbour
# Processing Record 32 of Set 11 | sierra grande
# Processing Record 33 of Set 11 | ariquemes
# Processing Record 34 of Set 11 | antsiranana
# Processing Record 35 of Set 11 | dunedin
# Processing Record 36 of Set 11 | bangui
# Processing Record 37 of Set 11 | santa vitoria
# Processing Record 38 of Set 11 | bubaque
# Processing Record 39 of Set 11 | ternate
# Processing Record 40 of Set 11 | amahai
# Processing Record 41 of Set 11 | guankou
# Processing Record 42 of Set 11 | eirunepe
# Processing Record 43 of Set 11 | xilitla
# Processing Record 44 of Set 11 | pop
# Processing Record 45 of Set 11 | nadym
# Processing Record 46 of Set 11 | tofol
# Processing Record 47 of Set 11 | khorramabad
# Processing Record 48 of Set 11 | sechura
# Processing Record 49 of Set 11 | conduaga
# Processing Record 0 of Set 12 | preobrazheniye
# Processing Record 1 of Set 12 | gurupi
# Processing Record 2 of Set 12 | bijie
# Processing Record 3 of Set 12 | carboneras
# Processing Record 4 of Set 12 | berezovyy
# Processing Record 5 of Set 12 | luwingu
# Processing Record 6 of Set 12 | port sudan
# Processing Record 7 of Set 12 | saint-francois
# Processing Record 8 of Set 12 | pont rouge
# Processing Record 9 of Set 12 | zeya
# Processing Record 10 of Set 12 | toamasina
# Processing Record 11 of Set 12 | loikaw
# Processing Record 12 of Set 12 | nainpur
# Processing Record 13 of Set 12 | udachny
# Processing Record 14 of Set 12 | bealanana
# Processing Record 15 of Set 12 | nova sintra
# Processing Record 16 of Set 12 | ghanzi
# Processing Record 17 of Set 12 | abashiri
# Processing Record 18 of Set 12 | mejit
# Processing Record 19 of Set 12 | katsuren-haebaru
# Processing Record 20 of Set 12 | castillos
# Processing Record 21 of Set 12 | hashimoto
# Processing Record 22 of Set 12 | kerema
# Processing Record 23 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 24 of Set 12 | mount pearl
# Processing Record 25 of Set 12 | nikolayevsk-on-amure
# Processing Record 26 of Set 12 | reggane
# Processing Record 27 of Set 12 | massawa
# Processing Record 28 of Set 12 | berezniki
# Processing Record 29 of Set 12 | labuan bajo
# Processing Record 30 of Set 12 | jinghong
# Processing Record 31 of Set 12 | xuddur
# Processing Record 32 of Set 12 | fuglafjordur
# Processing Record 33 of Set 12 | bhalki
# Processing Record 34 of Set 12 | hpa-an
# Processing Record 35 of Set 12 | saint albans
# Processing Record 36 of Set 12 | stebnyk
# Processing Record 37 of Set 12 | egilsstadir
# Processing Record 38 of Set 12 | mek'ele
# Processing Record 39 of Set 12 | nema
# Processing Record 40 of Set 12 | constitucion
# Processing Record 41 of Set 12 | cozumel
# Processing Record 42 of Set 12 | aykol
# City not found. Skipping...
# Processing Record 43 of Set 12 | vryheid
# Processing Record 44 of Set 12 | pukchil-lodongjagu
# Processing Record 45 of Set 12 | santa terezinha
# Processing Record 46 of Set 12 | hobyo
# Processing Record 47 of Set 12 | shortandy
# Processing Record 48 of Set 12 | fisterra
# Processing Record 49 of Set 12 | alamosa
# Processing Record 0 of Set 13 | yinchuan
# Processing Record 1 of Set 13 | jalai nur
# Processing Record 2 of Set 13 | whangarei
# Processing Record 3 of Set 13 | linares
# Processing Record 4 of Set 13 | iquitos
# Processing Record 5 of Set 13 | mermoz boabab
# Processing Record 6 of Set 13 | buta
# Processing Record 7 of Set 13 | igunga
# Processing Record 8 of Set 13 | labytnangi
# Processing Record 9 of Set 13 | mirzapur
# Processing Record 10 of Set 13 | fort bragg
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# {'coord': {'lon': -79.006, 'lat': 35.139}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 307.27, 'feels_like': 312.51, 'temp_min': 305.9, 'temp_max': 308.26, 'pressure': 1011, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 5.66, 'deg': 230}, 'clouds': {'all': 40}, 'dt': 1691439467, 'sys': {'type': 1, 'id': 5387, 'country': 'US', 'sunrise': 1691404172, 'sunset': 1691453648}, 'timezone': -14400, 'id': 6941080, 'name': 'Fort Bragg', 'cod': 200}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame({"City": city_name, 
                          "Lat": city_lat, 
                          "Lng": city_lon, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# Show Record Count
city_data_df.count()
# Out:
# City          584
# Lat           584
# Lng           584
# Max Temp      584
# Humidity      584
# Cloudiness    584
# Wind Speed    584
# Country       584
# Date          584
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ribeira Grande  38.5167  -28.7000    298.37        73          20
# 1           Kerikeri -35.2268  173.9474    281.61        91         100
# 2           Saldanha -33.0117   17.9442    286.18        92           0
# 3             Sukumo  32.9333  132.7333    299.57        96         100
# 4  Port-aux-Français -49.3500   70.2167    277.35        92         100
#
#    Wind Speed Country        Date
# 0        4.47      PT  1691439385
# 1        1.91      NZ  1691439385
# 2        3.85      ZA  1691439385
# 3        6.37      JP  1691439385
# 4       13.70      TF  1691439386

# %%
# Export the City_Data into a csv
os.makedirs("output_data", exist_ok=True)
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           Ribeira Grande  38.5167  -28.7000    298.37        73          20
# 1                 Kerikeri -35.2268  173.9474    281.61        91         100
# 2                 Saldanha -33.0117   17.9442    286.18        92           0
# 3                   Sukumo  32.9333  132.7333    299.57        96         100
# 4        Port-aux-Français -49.3500   70.2167    277.35        92         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.47      PT  1691439385
# 1              1.91      NZ  1691439385
# 2              3.85      ZA  1691439385
# 3              6.37      JP  1691439385
# 4             13.70      TF  1691439386

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_lat,city_max_temp, marker="o", color="blue")
plt.title("City Max Latitude vs Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_lat,city_humidity, marker="o", color="blue")
plt.title("City Max Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity)")

plt.show()


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_lat,city_clouds, marker="o", color="blue")
plt.title("Cit Max Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.show()


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_lat,city_wind, marker="o", color="blue")
plt.title("Cit Max Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Perform a linear regression
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
    regress_values = x_values * slope + intercept

# Define a function to create Linear Regression plots
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           Ribeira Grande  38.5167  -28.7000    298.37        73          20
# 3                   Sukumo  32.9333  132.7333    299.57        96         100
# 5                   Hasaki  35.7333  140.8333    299.99        90         100
# 7                  Stanley  54.8680   -1.6985    286.92        77          20
# 8        Saint Paul Harbor  57.7900 -152.4072    286.88        94         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.47      PT  1691439385
# 3              6.37      JP  1691439385
# 5              3.38      JP  1691439386
# 7              6.69      GB  1691439386
# 8              3.60      US  1691439386

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                 Kerikeri -35.2268  173.9474    281.61        91         100
# 2                 Saldanha -33.0117   17.9442    286.18        92           0
# 4        Port-aux-Français -49.3500   70.2167    277.35        92         100
# 6                Papatowai -46.5619  169.4708    278.21        82         100
# 11               Grytviken -54.2811  -36.5092    267.59        82          78
#
#          Wind Speed Country        Date
# City_ID
# 1              1.91      NZ  1691439385
# 2              3.85      ZA  1691439385
# 4             13.70      TF  1691439386
# 6              5.76      NZ  1691439386
# 11             4.85      GS  1691439387

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]


plot_linear_regression(x_values, y_values, "Temperature vs Latitude","Max Temp", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.66

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]


plot_linear_regression(x_values, y_values, "Temperature vs Latitude","Max Temp", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is 0.81

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]


plot_linear_regression(x_values, y_values, "Latitude vs Humidity","Humidity", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.05

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]


plot_linear_regression(x_values, y_values, "Latitude vs Humidity","Humidity", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.13

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]


plot_linear_regression(x_values, y_values, "Cloudiness vs Latitude","Cloudiness", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.12

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]


plot_linear_regression(x_values, y_values, "Cloudiness vs Latitude","Cloudiness", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is 0.01

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]


plot_linear_regression(x_values, y_values, "Wind Speed vs Latitude","Wind Speed", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.17

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]


plot_linear_regression(x_values, y_values, "Wind Speed vs Latitude","Wind Speed", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.01

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
