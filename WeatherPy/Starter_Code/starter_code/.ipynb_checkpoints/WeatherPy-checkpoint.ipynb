# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
import scipy.stats as st
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 626

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
#Each time this cell is run different sets of latitudes and longitudes are generated.

# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_name = []
city_data = []
city_lat = []
city_lon = []
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []
units = "imperial"
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&units={units}&APPID={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_name.append(response["name"])
        city_lat.append(response["coord"]["lat"])
        city_lon.append(response["coord"]["lon"])
        city_max_temp.append(response["main"]["temp_max"])
        city_humidity.append(response["main"]["humidity"])
        city_clouds.append(response["clouds"]["all"])
        city_wind.append(response["wind"]["speed"])
        city_country.append(response["sys"]["country"])
        city_date.append(response["dt"])

        # Append the City information into city_data list
        city_data.append({"City": city_name, 
                          "Lat": city_lat, 
                          "Lng": city_lon, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | yaren
# Processing Record 4 of Set 1 | whakatane
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | codajas
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | palu
# Processing Record 9 of Set 1 | alaghsas
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | grytviken
# Processing Record 12 of Set 1 | klyuchi
# Processing Record 13 of Set 1 | lazaro cardenas
# Processing Record 14 of Set 1 | gilgit
# Processing Record 15 of Set 1 | tomatlan
# Processing Record 16 of Set 1 | edinburgh of the seven seas
# Processing Record 17 of Set 1 | kolonia
# Processing Record 18 of Set 1 | buea
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | makurazaki
# Processing Record 21 of Set 1 | bethanie
# Processing Record 22 of Set 1 | port-aux-francais
# Processing Record 23 of Set 1 | port saint john's
# Processing Record 24 of Set 1 | antofagasta
# Processing Record 25 of Set 1 | oakland
# Processing Record 26 of Set 1 | ulsan
# Processing Record 27 of Set 1 | durango
# Processing Record 28 of Set 1 | college
# Processing Record 29 of Set 1 | nemuro
# Processing Record 30 of Set 1 | tuy hoa
# Processing Record 31 of Set 1 | biograd na moru
# Processing Record 32 of Set 1 | puerto natales
# Processing Record 33 of Set 1 | altai
# Processing Record 34 of Set 1 | hamilton
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | susuman
# Processing Record 37 of Set 1 | lata
# Processing Record 38 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 39 of Set 1 | enewetak
# Processing Record 40 of Set 1 | sligo
# Processing Record 41 of Set 1 | xam nua
# Processing Record 42 of Set 1 | hohoe
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | olonkinbyen
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | west island
# Processing Record 47 of Set 1 | atafu village
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | constantia
# Processing Record 0 of Set 2 | terra nova
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 3 of Set 2 | tobelo
# Processing Record 4 of Set 2 | sao joao da barra
# Processing Record 5 of Set 2 | vylkove
# Processing Record 6 of Set 2 | diamantino
# Processing Record 7 of Set 2 | veraval
# Processing Record 8 of Set 2 | ust-nera
# Processing Record 9 of Set 2 | margaret river
# Processing Record 10 of Set 2 | wailua homesteads
# Processing Record 11 of Set 2 | vadso
# Processing Record 12 of Set 2 | selfoss
# Processing Record 13 of Set 2 | shangzhi
# Processing Record 14 of Set 2 | papatowai
# Processing Record 15 of Set 2 | aguas vermelhas
# Processing Record 16 of Set 2 | carnarvon
# Processing Record 17 of Set 2 | lindi
# Processing Record 18 of Set 2 | ust'-ilimsk
# Processing Record 19 of Set 2 | vorgashor
# Processing Record 20 of Set 2 | port mathurin
# Processing Record 21 of Set 2 | hawaiian paradise park
# Processing Record 22 of Set 2 | calvinia
# Processing Record 23 of Set 2 | taltal
# Processing Record 24 of Set 2 | keflavik
# Processing Record 25 of Set 2 | al muwayh
# Processing Record 26 of Set 2 | anadyr
# Processing Record 27 of Set 2 | saudarkrokur
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | vallo della lucania
# Processing Record 30 of Set 2 | posto fiscal rolim de moura
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | happy valley-goose bay
# Processing Record 33 of Set 2 | bilibino
# Processing Record 34 of Set 2 | tshikapa
# Processing Record 35 of Set 2 | kyren
# Processing Record 36 of Set 2 | bonthe
# Processing Record 37 of Set 2 | robbah
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | mandan
# Processing Record 40 of Set 2 | lesosibirsk
# Processing Record 41 of Set 2 | amga
# Processing Record 42 of Set 2 | plastun
# Processing Record 43 of Set 2 | stanley
# Processing Record 44 of Set 2 | invercargill
# Processing Record 45 of Set 2 | kapuskasing
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | nkhotakota
# Processing Record 48 of Set 2 | maceio
# Processing Record 49 of Set 2 | cabo san lucas
# Processing Record 0 of Set 3 | ejea de los caballeros
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | lihue
# Processing Record 3 of Set 3 | terrasson-lavilledieu
# Processing Record 4 of Set 3 | sao vicente
# Processing Record 5 of Set 3 | colonia
# Processing Record 6 of Set 3 | rudsar
# Processing Record 7 of Set 3 | ar rutbah
# Processing Record 8 of Set 3 | san pedro pochutla
# Processing Record 9 of Set 3 | shenkursk
# Processing Record 10 of Set 3 | alvaraes
# Processing Record 11 of Set 3 | isafjordur
# Processing Record 12 of Set 3 | thunder bay
# Processing Record 13 of Set 3 | gadzhiyevo
# Processing Record 14 of Set 3 | st. john's
# Processing Record 15 of Set 3 | talitsa
# Processing Record 16 of Set 3 | utrik
# Processing Record 17 of Set 3 | soroti
# Processing Record 18 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 19 of Set 3 | glendive
# Processing Record 20 of Set 3 | la palma
# Processing Record 21 of Set 3 | christchurch
# Processing Record 22 of Set 3 | ushirombo
# Processing Record 23 of Set 3 | kununurra
# Processing Record 24 of Set 3 | pangai
# Processing Record 25 of Set 3 | nadi
# Processing Record 26 of Set 3 | lagrange
# Processing Record 27 of Set 3 | udachny
# Processing Record 28 of Set 3 | quepos
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | port blair
# Processing Record 31 of Set 3 | solnechnyy
# Processing Record 32 of Set 3 | coyuca de benitez
# Processing Record 33 of Set 3 | kuningan
# Processing Record 34 of Set 3 | tura
# Processing Record 35 of Set 3 | pisco
# Processing Record 36 of Set 3 | longyearbyen
# Processing Record 37 of Set 3 | buala
# Processing Record 38 of Set 3 | fort mcmurray
# Processing Record 39 of Set 3 | naze
# Processing Record 40 of Set 3 | egersund
# Processing Record 41 of Set 3 | ifrane
# Processing Record 42 of Set 3 | mejit
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | ilulissat
# Processing Record 45 of Set 3 | volda
# Processing Record 46 of Set 3 | nar'yan-mar
# Processing Record 47 of Set 3 | nuuk
# Processing Record 48 of Set 3 | saint-pierre
# Processing Record 49 of Set 3 | maputo
# Processing Record 0 of Set 4 | puerto santa
# Processing Record 1 of Set 4 | gidole
# Processing Record 2 of Set 4 | sandnessjoen
# Processing Record 3 of Set 4 | san mariano
# Processing Record 4 of Set 4 | mahenge
# Processing Record 5 of Set 4 | la'ie
# Processing Record 6 of Set 4 | magadan
# Processing Record 7 of Set 4 | puerto ayora
# Processing Record 8 of Set 4 | antsiranana
# Processing Record 9 of Set 4 | tralee
# Processing Record 10 of Set 4 | pristen'
# Processing Record 11 of Set 4 | puerto baquerizo moreno
# Processing Record 12 of Set 4 | qamdo
# Processing Record 13 of Set 4 | mount pearl
# Processing Record 14 of Set 4 | debila
# Processing Record 15 of Set 4 | dhidhdhoo
# Processing Record 16 of Set 4 | melfort
# Processing Record 17 of Set 4 | micheweni
# Processing Record 18 of Set 4 | bargara
# City not found. Skipping...
# Processing Record 19 of Set 4 | yatou
# Processing Record 20 of Set 4 | east london
# Processing Record 21 of Set 4 | hami
# Processing Record 22 of Set 4 | bay city
# Processing Record 23 of Set 4 | novoagansk
# Processing Record 24 of Set 4 | tynda
# Processing Record 25 of Set 4 | piti village
# Processing Record 26 of Set 4 | geroskipou
# City not found. Skipping...
# Processing Record 27 of Set 4 | bayan nur
# City not found. Skipping...
# Processing Record 28 of Set 4 | can-avid
# Processing Record 29 of Set 4 | doka
# Processing Record 30 of Set 4 | vangaindrano
# Processing Record 31 of Set 4 | yemva
# Processing Record 32 of Set 4 | burang
# Processing Record 33 of Set 4 | hammerfest
# Processing Record 34 of Set 4 | lavrio
# Processing Record 35 of Set 4 | revda
# Processing Record 36 of Set 4 | tenenkou
# Processing Record 37 of Set 4 | kristiansund
# Processing Record 38 of Set 4 | badger
# Processing Record 39 of Set 4 | hithadhoo
# Processing Record 40 of Set 4 | kataragama
# City not found. Skipping...
# Processing Record 41 of Set 4 | island harbour
# Processing Record 42 of Set 4 | zhangatas
# Processing Record 43 of Set 4 | nadym
# Processing Record 44 of Set 4 | punta arenas
# Processing Record 45 of Set 4 | iskateley
# Processing Record 46 of Set 4 | tiksi
# Processing Record 47 of Set 4 | miri
# Processing Record 48 of Set 4 | tsiombe
# Processing Record 49 of Set 4 | den burg
# Processing Record 0 of Set 5 | fale old settlement
# Processing Record 1 of Set 5 | lytham st annes
# Processing Record 2 of Set 5 | rudbar
# Processing Record 3 of Set 5 | ringkobing
# Processing Record 4 of Set 5 | afif
# Processing Record 5 of Set 5 | ingeniero jacobacci
# Processing Record 6 of Set 5 | kaga bandoro
# Processing Record 7 of Set 5 | villa la angostura
# Processing Record 8 of Set 5 | xining
# Processing Record 9 of Set 5 | robertsport
# Processing Record 10 of Set 5 | ola
# Processing Record 11 of Set 5 | minas de marcona
# Processing Record 12 of Set 5 | cidreira
# Processing Record 13 of Set 5 | fontanelas
# Processing Record 14 of Set 5 | afaahiti
# Processing Record 15 of Set 5 | hasaki
# Processing Record 16 of Set 5 | ancud
# Processing Record 17 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 18 of Set 5 | marsabit
# Processing Record 19 of Set 5 | lompoc
# Processing Record 20 of Set 5 | codrington
# Processing Record 21 of Set 5 | tarasovskiy
# Processing Record 22 of Set 5 | woods creek
# Processing Record 23 of Set 5 | ciudad lazaro cardenas
# Processing Record 24 of Set 5 | vila franca do campo
# Processing Record 25 of Set 5 | vilyuchinsk
# Processing Record 26 of Set 5 | inverell
# Processing Record 27 of Set 5 | kavaratti
# Processing Record 28 of Set 5 | nagqu
# Processing Record 29 of Set 5 | waingapu
# Processing Record 30 of Set 5 | talnakh
# Processing Record 31 of Set 5 | jebrail
# Processing Record 32 of Set 5 | port isabel
# Processing Record 33 of Set 5 | ishigaki
# Processing Record 34 of Set 5 | wahlstedt
# Processing Record 35 of Set 5 | alice springs
# Processing Record 36 of Set 5 | fortaleza
# Processing Record 37 of Set 5 | mitchell
# Processing Record 38 of Set 5 | westerland
# Processing Record 39 of Set 5 | bel ombre
# Processing Record 40 of Set 5 | zambezi
# Processing Record 41 of Set 5 | geraldton
# Processing Record 42 of Set 5 | al lagowa
# Processing Record 43 of Set 5 | angaur state
# Processing Record 44 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 45 of Set 5 | arkhangel'sk
# Processing Record 46 of Set 5 | trincomalee
# Processing Record 47 of Set 5 | puerto carreno
# Processing Record 48 of Set 5 | raja
# Processing Record 49 of Set 5 | khandyga
# Processing Record 0 of Set 6 | argo
# Processing Record 1 of Set 6 | al fuwayliq
# Processing Record 2 of Set 6 | okha
# Processing Record 3 of Set 6 | tangalle
# Processing Record 4 of Set 6 | mammoth lakes
# Processing Record 5 of Set 6 | luderitz
# Processing Record 6 of Set 6 | phu kradueng
# Processing Record 7 of Set 6 | flying fish cove
# Processing Record 8 of Set 6 | taroa
# Processing Record 9 of Set 6 | santana
# Processing Record 10 of Set 6 | pemangkat
# Processing Record 11 of Set 6 | yamada
# Processing Record 12 of Set 6 | al mindak
# Processing Record 13 of Set 6 | aasiaat
# Processing Record 14 of Set 6 | tabou
# Processing Record 15 of Set 6 | show low
# Processing Record 16 of Set 6 | madera
# Processing Record 17 of Set 6 | arraial do cabo
# Processing Record 18 of Set 6 | turpan
# Processing Record 19 of Set 6 | as sulayyil
# Processing Record 20 of Set 6 | carolina beach
# Processing Record 21 of Set 6 | rabaul
# Processing Record 22 of Set 6 | la ronge
# Processing Record 23 of Set 6 | rumoi
# Processing Record 24 of Set 6 | callao
# Processing Record 25 of Set 6 | sijunjung
# Processing Record 26 of Set 6 | weno
# Processing Record 27 of Set 6 | ampanihy
# Processing Record 28 of Set 6 | ajdabiya
# Processing Record 29 of Set 6 | la passe
# Processing Record 30 of Set 6 | holualoa
# Processing Record 31 of Set 6 | shirvan
# Processing Record 32 of Set 6 | jacobabad
# Processing Record 33 of Set 6 | juan griego
# Processing Record 34 of Set 6 | santa cruz
# Processing Record 35 of Set 6 | markovo
# Processing Record 36 of Set 6 | berdigestyakh
# Processing Record 37 of Set 6 | saipan
# Processing Record 38 of Set 6 | opuwo
# Processing Record 39 of Set 6 | iquique
# Processing Record 40 of Set 6 | new norfolk
# Processing Record 41 of Set 6 | pangoa
# Processing Record 42 of Set 6 | colonia del sacramento
# Processing Record 43 of Set 6 | agat village
# Processing Record 44 of Set 6 | viedma
# Processing Record 45 of Set 6 | praia da vitoria
# Processing Record 46 of Set 6 | karoi
# Processing Record 47 of Set 6 | al jahra'
# Processing Record 48 of Set 6 | nova vicosa
# Processing Record 49 of Set 6 | yorkton
# Processing Record 0 of Set 7 | kaithal
# Processing Record 1 of Set 7 | mata-utu
# Processing Record 2 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 3 of Set 7 | kayangel
# Processing Record 4 of Set 7 | sandy
# Processing Record 5 of Set 7 | whitehorse
# Processing Record 6 of Set 7 | dunedin
# Processing Record 7 of Set 7 | tadpatri
# Processing Record 8 of Set 7 | el granada
# Processing Record 9 of Set 7 | bay harbor
# Processing Record 10 of Set 7 | muzayri'
# City not found. Skipping...
# Processing Record 11 of Set 7 | n'zeto
# Processing Record 12 of Set 7 | christiana
# Processing Record 13 of Set 7 | loikaw
# Processing Record 14 of Set 7 | sinabang
# Processing Record 15 of Set 7 | kuala belait
# Processing Record 16 of Set 7 | thinadhoo
# Processing Record 17 of Set 7 | tchintabaraden
# Processing Record 18 of Set 7 | ebon
# Processing Record 19 of Set 7 | chonchi
# Processing Record 20 of Set 7 | sassandra
# Processing Record 21 of Set 7 | namibe
# Processing Record 22 of Set 7 | puerto montt
# Processing Record 23 of Set 7 | shenjiamen
# Processing Record 24 of Set 7 | pacific grove
# Processing Record 25 of Set 7 | taoudenni
# Processing Record 26 of Set 7 | matamey
# Processing Record 27 of Set 7 | bella vista
# Processing Record 28 of Set 7 | crane
# Processing Record 29 of Set 7 | qaqortoq
# Processing Record 30 of Set 7 | quirinopolis
# Processing Record 31 of Set 7 | sheboygan falls
# Processing Record 32 of Set 7 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 33 of Set 7 | san patricio
# Processing Record 34 of Set 7 | zouerate
# Processing Record 35 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 36 of Set 7 | victoria
# Processing Record 37 of Set 7 | vasilikon
# Processing Record 38 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 39 of Set 7 | nouadhibou
# Processing Record 40 of Set 7 | amursk
# Processing Record 41 of Set 7 | velykyy bereznyy
# City not found. Skipping...
# Processing Record 42 of Set 7 | the pas
# Processing Record 43 of Set 7 | galeana
# Processing Record 44 of Set 7 | tofol
# Processing Record 45 of Set 7 | riviere-du-loup
# Processing Record 46 of Set 7 | inhambane
# Processing Record 47 of Set 7 | peniche
# Processing Record 48 of Set 7 | bejaia
# Processing Record 49 of Set 7 | tuba city
# Processing Record 0 of Set 8 | howard springs
# Processing Record 1 of Set 8 | manggar
# Processing Record 2 of Set 8 | el alto
# Processing Record 3 of Set 8 | manavalakurichi
# Processing Record 4 of Set 8 | ripoll
# Processing Record 5 of Set 8 | abu 'arish
# City not found. Skipping...
# Processing Record 6 of Set 8 | prado
# Processing Record 7 of Set 8 | recani
# Processing Record 8 of Set 8 | kuzovatovo
# Processing Record 9 of Set 8 | kingston
# Processing Record 10 of Set 8 | sao felix do xingu
# Processing Record 11 of Set 8 | uzgen
# Processing Record 12 of Set 8 | guerrero negro
# Processing Record 13 of Set 8 | guane
# Processing Record 14 of Set 8 | yuzhno-kurilsk
# Processing Record 15 of Set 8 | calca
# Processing Record 16 of Set 8 | kabalo
# Processing Record 17 of Set 8 | looe
# Processing Record 18 of Set 8 | bac lieu
# Processing Record 19 of Set 8 | oodweyne
# Processing Record 20 of Set 8 | kiruna
# Processing Record 21 of Set 8 | zapolyarnyy
# Processing Record 22 of Set 8 | antonio enes
# Processing Record 23 of Set 8 | popoli
# Processing Record 24 of Set 8 | gereida
# Processing Record 25 of Set 8 | yerofey pavlovich
# Processing Record 26 of Set 8 | mandal
# Processing Record 27 of Set 8 | mananjary
# Processing Record 28 of Set 8 | khorixas
# Processing Record 29 of Set 8 | las tablas
# Processing Record 30 of Set 8 | chowchilla
# Processing Record 31 of Set 8 | bandar lampung
# Processing Record 32 of Set 8 | kerikeri
# Processing Record 33 of Set 8 | takaungu
# Processing Record 34 of Set 8 | brumunddal
# Processing Record 35 of Set 8 | sungailiat
# Processing Record 36 of Set 8 | salalah
# Processing Record 37 of Set 8 | charcas
# Processing Record 38 of Set 8 | santa elena de uairen
# Processing Record 39 of Set 8 | portland
# Processing Record 40 of Set 8 | dakhla
# Processing Record 41 of Set 8 | mayfield
# Processing Record 42 of Set 8 | uusikaupunki
# Processing Record 43 of Set 8 | hotan
# Processing Record 44 of Set 8 | nova sintra
# Processing Record 45 of Set 8 | kampung sungai ara
# Processing Record 46 of Set 8 | fort st. john
# Processing Record 47 of Set 8 | i-n-salah
# Processing Record 48 of Set 8 | pimentel
# Processing Record 49 of Set 8 | macapa
# Processing Record 0 of Set 9 | motygino
# Processing Record 1 of Set 9 | sosenskiy
# Processing Record 2 of Set 9 | tanjung selor
# City not found. Skipping...
# Processing Record 3 of Set 9 | savave village
# City not found. Skipping...
# Processing Record 4 of Set 9 | turek
# Processing Record 5 of Set 9 | lebu
# Processing Record 6 of Set 9 | inarajan village
# Processing Record 7 of Set 9 | labrador city
# Processing Record 8 of Set 9 | miyaly
# Processing Record 9 of Set 9 | hilo
# Processing Record 10 of Set 9 | nizhnesortymskiy
# Processing Record 11 of Set 9 | akureyri
# Processing Record 12 of Set 9 | astrakhan
# Processing Record 13 of Set 9 | park city
# Processing Record 14 of Set 9 | sargatskoye
# Processing Record 15 of Set 9 | worthington
# Processing Record 16 of Set 9 | saldanha
# Processing Record 17 of Set 9 | saint-francois
# Processing Record 18 of Set 9 | gole
# Processing Record 19 of Set 9 | bubaque
# Processing Record 20 of Set 9 | greenville
# Processing Record 21 of Set 9 | dudinka
# Processing Record 22 of Set 9 | dauphin
# Processing Record 23 of Set 9 | abilene
# Processing Record 24 of Set 9 | cotoca
# Processing Record 25 of Set 9 | santa ana
# Processing Record 26 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 27 of Set 9 | spas-demensk
# Processing Record 28 of Set 9 | olbia
# Processing Record 29 of Set 9 | san fernando de apure
# Processing Record 30 of Set 9 | kill devil hills
# Processing Record 31 of Set 9 | berezovyy
# Processing Record 32 of Set 9 | tromso
# Processing Record 33 of Set 9 | coquimbo
# Processing Record 34 of Set 9 | boa vista
# Processing Record 35 of Set 9 | carboneras
# Processing Record 36 of Set 9 | sovetskiy
# Processing Record 37 of Set 9 | newman
# Processing Record 38 of Set 9 | lakki
# Processing Record 39 of Set 9 | orcopampa
# Processing Record 40 of Set 9 | ambon
# Processing Record 41 of Set 9 | camocim
# Processing Record 42 of Set 9 | lexington
# Processing Record 43 of Set 9 | mukalla
# Processing Record 44 of Set 9 | barwani
# Processing Record 45 of Set 9 | kushiro
# Processing Record 46 of Set 9 | wuyo
# Processing Record 47 of Set 9 | atlantic beach
# Processing Record 48 of Set 9 | palangkaraya
# Processing Record 49 of Set 9 | boguchany
# Processing Record 0 of Set 10 | sisimiut
# Processing Record 1 of Set 10 | nuku'alofa
# Processing Record 2 of Set 10 | ginir
# Processing Record 3 of Set 10 | haiku-pauwela
# Processing Record 4 of Set 10 | shinkafi
# Processing Record 5 of Set 10 | igrim
# Processing Record 6 of Set 10 | abqaiq
# Processing Record 7 of Set 10 | sahar
# Processing Record 8 of Set 10 | north bend
# Processing Record 9 of Set 10 | machico
# Processing Record 10 of Set 10 | cockburn town
# Processing Record 11 of Set 10 | qobustan
# Processing Record 12 of Set 10 | cold lake
# Processing Record 13 of Set 10 | south sioux city
# Processing Record 14 of Set 10 | labytnangi
# Processing Record 15 of Set 10 | ritchie
# Processing Record 16 of Set 10 | langepas
# Processing Record 17 of Set 10 | midvagur
# Processing Record 18 of Set 10 | sikasso
# Processing Record 19 of Set 10 | laguna
# Processing Record 20 of Set 10 | pandan
# Processing Record 21 of Set 10 | nizhneudinsk
# Processing Record 22 of Set 10 | ras gharib
# City not found. Skipping...
# Processing Record 23 of Set 10 | klaksvik
# Processing Record 24 of Set 10 | tikrit
# Processing Record 25 of Set 10 | salekhard
# Processing Record 26 of Set 10 | el kef
# Processing Record 27 of Set 10 | papao
# Processing Record 28 of Set 10 | nguigmi
# Processing Record 29 of Set 10 | sabang
# Processing Record 30 of Set 10 | jijiang
# Processing Record 31 of Set 10 | kuta
# Processing Record 32 of Set 10 | sao luis de montes belos
# Processing Record 33 of Set 10 | tegucigalpa
# Processing Record 34 of Set 10 | malemort-sur-correze
# Processing Record 35 of Set 10 | buka
# Processing Record 36 of Set 10 | mirabad
# Processing Record 37 of Set 10 | shingu
# Processing Record 38 of Set 10 | tbeng meanchey
# Processing Record 39 of Set 10 | santa terezinha
# Processing Record 40 of Set 10 | timmins
# Processing Record 41 of Set 10 | taseyevo
# Processing Record 42 of Set 10 | cabedelo
# Processing Record 43 of Set 10 | chamical
# Processing Record 44 of Set 10 | barda
# Processing Record 45 of Set 10 | kayyerkan
# Processing Record 46 of Set 10 | taiynsha
# Processing Record 47 of Set 10 | thurso
# Processing Record 48 of Set 10 | sousa
# Processing Record 49 of Set 10 | illapel
# Processing Record 0 of Set 11 | longonjo
# Processing Record 1 of Set 11 | saint-philippe
# Processing Record 2 of Set 11 | nueva concepcion
# Processing Record 3 of Set 11 | laojunmiao
# Processing Record 4 of Set 11 | franklin
# Processing Record 5 of Set 11 | al bawiti
# Processing Record 6 of Set 11 | san antonio de pale
# Processing Record 7 of Set 11 | oriximina
# Processing Record 8 of Set 11 | yongchuan
# Processing Record 9 of Set 11 | ulladulla
# Processing Record 10 of Set 11 | faya-largeau
# Processing Record 11 of Set 11 | bodo
# Processing Record 12 of Set 11 | boa esperanca do sul
# Processing Record 13 of Set 11 | kanggye
# Processing Record 14 of Set 11 | itoman
# Processing Record 15 of Set 11 | bandiagara
# Processing Record 16 of Set 11 | we
# City not found. Skipping...
# Processing Record 17 of Set 11 | tobi village
# City not found. Skipping...
# Processing Record 18 of Set 11 | howrah
# Processing Record 19 of Set 11 | muhos
# Processing Record 20 of Set 11 | beteza
# City not found. Skipping...
# Processing Record 21 of Set 11 | amahai
# Processing Record 22 of Set 11 | itaueira
# Processing Record 23 of Set 11 | vrangel'
# Processing Record 24 of Set 11 | sao paulo de olivenca
# Processing Record 25 of Set 11 | desaguadero
# Processing Record 26 of Set 11 | ausa
# Processing Record 27 of Set 11 | vernon
# Processing Record 28 of Set 11 | paidha
# Processing Record 29 of Set 11 | ponta delgada
# Processing Record 30 of Set 11 | prineville
# Processing Record 31 of Set 11 | noshiro
# Processing Record 32 of Set 11 | banur
# Processing Record 33 of Set 11 | mangrol
# Processing Record 34 of Set 11 | charef
# Processing Record 35 of Set 11 | matsuyama
# Processing Record 36 of Set 11 | kalianget
# Processing Record 37 of Set 11 | kuqa
# Processing Record 38 of Set 11 | katima mulilo
# Processing Record 39 of Set 11 | aykhal
# Processing Record 40 of Set 11 | uturoa
# Processing Record 41 of Set 11 | ribeira brava
# Processing Record 42 of Set 11 | tanjung pinang
# Processing Record 43 of Set 11 | chancay
# Processing Record 44 of Set 11 | sydney
# Processing Record 45 of Set 11 | kamyshin
# Processing Record 46 of Set 11 | mao
# Processing Record 47 of Set 11 | gueltat zemmour
# City not found. Skipping...
# Processing Record 48 of Set 11 | eyl
# Processing Record 49 of Set 11 | nyurba
# Processing Record 0 of Set 12 | east ballina
# Processing Record 1 of Set 12 | necochea
# Processing Record 2 of Set 12 | tazovsky
# Processing Record 3 of Set 12 | idabel
# Processing Record 4 of Set 12 | isabela
# Processing Record 5 of Set 12 | broome
# Processing Record 6 of Set 12 | elizabeth city
# Processing Record 7 of Set 12 | luanco
# Processing Record 8 of Set 12 | serhiyivka
# Processing Record 9 of Set 12 | bandarbeyla
# Processing Record 10 of Set 12 | candelaria
# Processing Record 11 of Set 12 | arno
# Processing Record 12 of Set 12 | kalix
# Processing Record 13 of Set 12 | 'ohonua
# City not found. Skipping...
# Processing Record 14 of Set 12 | lyuban'
# Processing Record 15 of Set 12 | erenhot
# Processing Record 16 of Set 12 | acarau
# Processing Record 17 of Set 12 | fada
# Processing Record 18 of Set 12 | polyarnyy
# Processing Record 19 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 20 of Set 12 | juneau
# Processing Record 21 of Set 12 | oudtshoorn
# Processing Record 22 of Set 12 | kuching
# Processing Record 23 of Set 12 | torre de moncorvo
# Processing Record 24 of Set 12 | loango
# Processing Record 25 of Set 12 | auki
# Processing Record 26 of Set 12 | giresun
# Processing Record 27 of Set 12 | golpazari
# Processing Record 28 of Set 12 | morant bay
# Processing Record 29 of Set 12 | kyzyl
# Processing Record 30 of Set 12 | tsiroanomandidy
# Processing Record 31 of Set 12 | bairnsdale
# Processing Record 32 of Set 12 | al badari
# Processing Record 33 of Set 12 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 34 of Set 12 | olyokminsk
# Processing Record 35 of Set 12 | kencong
# Processing Record 36 of Set 12 | fortuna
# Processing Record 37 of Set 12 | pacasmayo
# Processing Record 38 of Set 12 | kone
# Processing Record 39 of Set 12 | havre
# Processing Record 40 of Set 12 | maragogi
# Processing Record 41 of Set 12 | wynyard
# Processing Record 42 of Set 12 | ramadi
# Processing Record 43 of Set 12 | basco
# Processing Record 44 of Set 12 | demerval lobao
# Processing Record 45 of Set 12 | richland
# Processing Record 46 of Set 12 | puerto deseado
# Processing Record 47 of Set 12 | mont-dore
# Processing Record 48 of Set 12 | aberdeen
# Processing Record 49 of Set 12 | houghton
# Processing Record 0 of Set 13 | ulanhot
# Processing Record 1 of Set 13 | dongola
# Processing Record 2 of Set 13 | el haouaria
# Processing Record 3 of Set 13 | abepura
# Processing Record 4 of Set 13 | miles city
# Processing Record 5 of Set 13 | malindi
# Processing Record 6 of Set 13 | arba minch
# Processing Record 7 of Set 13 | chom thong
# Processing Record 8 of Set 13 | diffa
# Processing Record 9 of Set 13 | richards bay
# Processing Record 10 of Set 13 | fort bragg
# Processing Record 11 of Set 13 | fisterra
# Processing Record 12 of Set 13 | puerto armuelles
# Processing Record 13 of Set 13 | les cayes
# Processing Record 14 of Set 13 | greymouth
# Processing Record 15 of Set 13 | vigan
# Processing Record 16 of Set 13 | twon-brass
# Processing Record 17 of Set 13 | qarauyl
# Processing Record 18 of Set 13 | ilebo
# Processing Record 19 of Set 13 | ryki
# Processing Record 20 of Set 13 | kapa'a
# Processing Record 21 of Set 13 | knyaze-volkonskoye
# Processing Record 22 of Set 13 | piacabucu
# Processing Record 23 of Set 13 | tver
# Processing Record 24 of Set 13 | bikenibeu village
# Processing Record 25 of Set 13 | kavieng
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# {'coord': {'lon': 150.7967, 'lat': -2.5744}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 80.15, 'feels_like': 84.27, 'temp_min': 80.15, 'temp_max': 80.15, 'pressure': 1011, 'humidity': 78, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 7.27, 'deg': 137, 'gust': 12.01}, 'clouds': {'all': 99}, 'dt': 1691513774, 'sys': {'country': 'PG', 'sunrise': 1691524919, 'sunset': 1691568178}, 'timezone': 36000, 'id': 2094342, 'name': 'Kavieng', 'cod': 200}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame({"City": city_name, 
                          "Lat": city_lat, 
                          "Lng": city_lon, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# Show Record Count
city_data_df.count()
# Out:
# City          600
# Lat           600
# Lng           600
# Max Temp      600
# Humidity      600
# Cloudiness    600
# Wind Speed    600
# Country       600
# Date          600
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Adamstown -25.0660 -130.1015     72.09        87          98       28.10
# 1     Waitangi -43.9535 -176.5597     47.82        96         100        1.99
# 2        Yaren  -0.5472  166.9160     82.40        72          93        7.87
# 3    Whakatane -37.9585  176.9854     39.78        99          16        5.91
# 4  Port Alfred -33.5906   26.8910     61.18        86          96        4.00
#
#   Country        Date
# 0      PN  1691513707
# 1      NZ  1691513707
# 2      NR  1691513707
# 3      NZ  1691513707
# 4      ZA  1691513707

# %%
# Export the City_Data into a csv
os.makedirs("output_data", exist_ok=True)
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          Adamstown -25.0660 -130.1015     72.09        87          98
# 1           Waitangi -43.9535 -176.5597     47.82        96         100
# 2              Yaren  -0.5472  166.9160     82.40        72          93
# 3          Whakatane -37.9585  176.9854     39.78        99          16
# 4        Port Alfred -33.5906   26.8910     61.18        86          96
#
#          Wind Speed Country        Date
# City_ID
# 0             28.10      PN  1691513707
# 1              1.99      NZ  1691513707
# 2              7.87      NR  1691513707
# 3              5.91      NZ  1691513707
# 4              4.00      ZA  1691513707

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_lat,city_max_temp, marker="o", color="blue")
plt.title("City Max Latitude vs Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_lat,city_humidity, marker="o", color="blue")
plt.title("City Max Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity)")

plt.show()


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_lat,city_clouds, marker="o", color="blue")
plt.title("Cit Max Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.show()


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_lat,city_wind, marker="o", color="blue")
plt.title("Cit Max Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Perform a linear regression
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
    regress_values = x_values * slope + intercept

# Define a function to create Linear Regression plots
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 6                Iqaluit  63.7506  -68.5145     44.33        87          40
# 8               Alaghsas  17.0187    8.0168     96.69        41          20
# 9                  Sitka  57.0531 -135.3300     57.09        94         100
# 11               Klyuchi  52.2667   79.1667     69.39        41          36
# 12       Lázaro Cárdenas  17.9583 -102.2000     89.73        63          23
#
#          Wind Speed Country        Date
# City_ID
# 6             12.66      CA  1691513707
# 8              5.75      NE  1691513708
# 9             11.50      US  1691513708
# 11             1.03      RU  1691513708
# 12             4.38      MX  1691513708

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          Adamstown -25.0660 -130.1015     72.09        87          98
# 1           Waitangi -43.9535 -176.5597     47.82        96         100
# 2              Yaren  -0.5472  166.9160     82.40        72          93
# 3          Whakatane -37.9585  176.9854     39.78        99          16
# 4        Port Alfred -33.5906   26.8910     61.18        86          96
#
#          Wind Speed Country        Date
# City_ID
# 0             28.10      PN  1691513707
# 1              1.99      NZ  1691513707
# 2              7.87      NR  1691513707
# 3              5.91      NZ  1691513707
# 4              4.00      ZA  1691513707

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]


plot_linear_regression(x_values, y_values, "Temperature vs Latitude","Max Temp", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.6

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]


plot_linear_regression(x_values, y_values, "Temperature vs Latitude","Max Temp", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is 0.84

# %% [markdown]
# **Discussion about the linear relationship:** <br>
# In the northern hemisphere, there is a negative correlation between latitude and temperature. If you are father away from the equator, the temperature will be colder.
# In the southern hemisphere, there is a positivte correlation between latitude and temperature. Locations along the equator have higher temperatures.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]


plot_linear_regression(x_values, y_values, "Latitude vs Humidity","Humidity", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.02

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]


plot_linear_regression(x_values, y_values, "Latitude vs Humidity","Humidity", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.19

# %% [markdown]
# **Discussion about the linear relationship:** <br>
# The analysis suggests that there is not much of a relationship between humidity and latitude in both northern and southern hemispheres. The values do not follow much of a pattern.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]


plot_linear_regression(x_values, y_values, "Cloudiness vs Latitude","Cloudiness", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.09

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]


plot_linear_regression(x_values, y_values, "Cloudiness vs Latitude","Cloudiness", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.13

# %% [markdown]
# **Discussion about the linear relationship:** <br>
# The analysis suggests that there is not much of a relationship between cloudiness and latitude in both northern and southern hemispheres. Cloudiess is affected by differt factors such as precipitation and temperature.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]


plot_linear_regression(x_values, y_values, "Wind Speed vs Latitude","Wind Speed", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.01

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]


plot_linear_regression(x_values, y_values, "Wind Speed vs Latitude","Wind Speed", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.08

# %% [markdown]
# **Discussion about the linear relationship:** <br>
# In both northern and southern hemispheres, there is a concentration of data points at lower wind speeds across all latitudes. Although this can be observed, there is still not a correlations between latitude and wind speed.
