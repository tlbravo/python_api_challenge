# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
import scipy.stats as st
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 599

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
#Each time this cell is run different sets of latitudes and longitudes are generated.

# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_name = []
city_data = []
city_lat = []
city_lon = []
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []
units = "imperial"
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&units={units}&APPID={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_name.append(response["name"])
        city_lat.append(response["coord"]["lat"])
        city_lon.append(response["coord"]["lon"])
        city_max_temp.append(response["main"]["temp_max"])
        city_humidity.append(response["main"]["humidity"])
        city_clouds.append(response["clouds"]["all"])
        city_wind.append(response["wind"]["speed"])
        city_country.append(response["sys"]["country"])
        city_date.append(response["dt"])

        # Append the City information into city_data list
        city_data.append({"City": city_name, 
                          "Lat": city_lat, 
                          "Lng": city_lon, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto natales
# Processing Record 2 of Set 1 | mersa matruh
# Processing Record 3 of Set 1 | vilyuysk
# Processing Record 4 of Set 1 | curitibanos
# Processing Record 5 of Set 1 | zuyevka
# Processing Record 6 of Set 1 | vorgashor
# Processing Record 7 of Set 1 | sibolga
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | labrador city
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | adamstown
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | mount pearl
# Processing Record 15 of Set 1 | zhukovo
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | topolobampo
# Processing Record 18 of Set 1 | west island
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | egilsstadir
# Processing Record 21 of Set 1 | alofi
# Processing Record 22 of Set 1 | kapa'a
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | ust-nera
# Processing Record 25 of Set 1 | bel ombre
# Processing Record 26 of Set 1 | ilulissat
# Processing Record 27 of Set 1 | melekeok village
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | peterhead
# Processing Record 30 of Set 1 | ghormach
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | kirakira
# Processing Record 33 of Set 1 | tolanaro
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | geraldton
# Processing Record 36 of Set 1 | afaahiti
# Processing Record 37 of Set 1 | boyolangu
# Processing Record 38 of Set 1 | umluj
# Processing Record 39 of Set 1 | 'anat al qadimah
# Processing Record 40 of Set 1 | west richland
# Processing Record 41 of Set 1 | shahba
# Processing Record 42 of Set 1 | kataragama
# City not found. Skipping...
# Processing Record 43 of Set 1 | edinburgh of the seven seas
# Processing Record 44 of Set 1 | olonkinbyen
# Processing Record 45 of Set 1 | hamilton
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | college
# Processing Record 48 of Set 1 | aldinga beach
# Processing Record 49 of Set 1 | banda aceh
# Processing Record 50 of Set 1 | mount isa
# Processing Record 0 of Set 2 | blackmans bay
# Processing Record 1 of Set 2 | saipan
# Processing Record 2 of Set 2 | kruisfontein
# Processing Record 3 of Set 2 | vadso
# Processing Record 4 of Set 2 | stanley
# Processing Record 5 of Set 2 | tofol
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | port-aux-francais
# Processing Record 11 of Set 2 | port mathurin
# Processing Record 12 of Set 2 | fada
# Processing Record 13 of Set 2 | old orchard beach
# Processing Record 14 of Set 2 | constantia
# Processing Record 15 of Set 2 | mount gambier
# Processing Record 16 of Set 2 | moyynkum
# Processing Record 17 of Set 2 | iqaluit
# Processing Record 18 of Set 2 | benguela
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | monrovia
# Processing Record 21 of Set 2 | ca mau
# Processing Record 22 of Set 2 | tura
# Processing Record 23 of Set 2 | mandan
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | lazaro cardenas
# Processing Record 26 of Set 2 | wailua homesteads
# Processing Record 27 of Set 2 | tikhvin
# Processing Record 28 of Set 2 | hovd
# Processing Record 29 of Set 2 | kuta
# Processing Record 30 of Set 2 | san luis de la loma
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | gadzhiyevo
# Processing Record 35 of Set 2 | wuwei
# Processing Record 36 of Set 2 | la sarre
# Processing Record 37 of Set 2 | bridgewater
# Processing Record 38 of Set 2 | udachny
# Processing Record 39 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 40 of Set 2 | pionerskiy
# Processing Record 41 of Set 2 | ola
# Processing Record 42 of Set 2 | badiyah
# Processing Record 43 of Set 2 | bodaybo
# Processing Record 44 of Set 2 | invercargill
# Processing Record 45 of Set 2 | fale old settlement
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | uray
# Processing Record 48 of Set 2 | rodna
# Processing Record 49 of Set 2 | touros
# Processing Record 0 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 1 of Set 3 | kimbe
# Processing Record 2 of Set 3 | greenville
# Processing Record 3 of Set 3 | iquique
# Processing Record 4 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 5 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 6 of Set 3 | eirunepe
# Processing Record 7 of Set 3 | tommot
# Processing Record 8 of Set 3 | minas de marcona
# Processing Record 9 of Set 3 | greymouth
# Processing Record 10 of Set 3 | kailua-kona
# Processing Record 11 of Set 3 | sogndal
# Processing Record 12 of Set 3 | queenstown
# Processing Record 13 of Set 3 | kismayo
# Processing Record 14 of Set 3 | fortaleza
# Processing Record 15 of Set 3 | coxen hole
# Processing Record 16 of Set 3 | polyarnyy
# Processing Record 17 of Set 3 | isafjordur
# Processing Record 18 of Set 3 | faya-largeau
# Processing Record 19 of Set 3 | utrik
# Processing Record 20 of Set 3 | vanino
# Processing Record 21 of Set 3 | mossel bay
# Processing Record 22 of Set 3 | am djarass
# City not found. Skipping...
# Processing Record 23 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 24 of Set 3 | ar rutbah
# Processing Record 25 of Set 3 | williams lake
# Processing Record 26 of Set 3 | anatuya
# Processing Record 27 of Set 3 | talnakh
# Processing Record 28 of Set 3 | port-vila
# Processing Record 29 of Set 3 | takamaka
# City not found. Skipping...
# Processing Record 30 of Set 3 | anabar
# City not found. Skipping...
# Processing Record 31 of Set 3 | anadyr
# Processing Record 32 of Set 3 | copala
# Processing Record 33 of Set 3 | impfondo
# Processing Record 34 of Set 3 | chonchi
# Processing Record 35 of Set 3 | meiganga
# Processing Record 36 of Set 3 | taoudenni
# Processing Record 37 of Set 3 | beauharnois
# Processing Record 38 of Set 3 | ancud
# Processing Record 39 of Set 3 | xining
# Processing Record 40 of Set 3 | cururupu
# Processing Record 41 of Set 3 | enewetak
# Processing Record 42 of Set 3 | ruidoso
# Processing Record 43 of Set 3 | altamira
# Processing Record 44 of Set 3 | bireun
# Processing Record 45 of Set 3 | hermanus
# Processing Record 46 of Set 3 | smiths falls
# Processing Record 47 of Set 3 | port-cartier
# Processing Record 48 of Set 3 | glace bay
# Processing Record 49 of Set 3 | port macquarie
# Processing Record 0 of Set 4 | margaret river
# Processing Record 1 of Set 4 | puro
# Processing Record 2 of Set 4 | howrah
# Processing Record 3 of Set 4 | pashkovskiy
# Processing Record 4 of Set 4 | flying fish cove
# Processing Record 5 of Set 4 | aykhal
# Processing Record 6 of Set 4 | bodo
# Processing Record 7 of Set 4 | charlottetown
# Processing Record 8 of Set 4 | slave lake
# Processing Record 9 of Set 4 | acatlan de osorio
# Processing Record 10 of Set 4 | smolyan
# Processing Record 11 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 12 of Set 4 | wynyard
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | pisco
# Processing Record 15 of Set 4 | dudinka
# Processing Record 16 of Set 4 | la ronge
# Processing Record 17 of Set 4 | daliang
# Processing Record 18 of Set 4 | plast
# Processing Record 19 of Set 4 | altay
# Processing Record 20 of Set 4 | viedma
# Processing Record 21 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 22 of Set 4 | mugia
# Processing Record 23 of Set 4 | masterton
# Processing Record 24 of Set 4 | estevan
# Processing Record 25 of Set 4 | selfoss
# Processing Record 26 of Set 4 | papatowai
# Processing Record 27 of Set 4 | cestos city
# Processing Record 28 of Set 4 | pea ridge
# Processing Record 29 of Set 4 | san patricio
# Processing Record 30 of Set 4 | iskateley
# Processing Record 31 of Set 4 | sandnessjoen
# Processing Record 32 of Set 4 | jamestown
# Processing Record 33 of Set 4 | trapani
# Processing Record 34 of Set 4 | rio grande
# Processing Record 35 of Set 4 | katsuura
# Processing Record 36 of Set 4 | longboat key
# Processing Record 37 of Set 4 | at-bashi
# Processing Record 38 of Set 4 | newman
# Processing Record 39 of Set 4 | kargopol'
# Processing Record 40 of Set 4 | santa rosa
# Processing Record 41 of Set 4 | sao jose da coroa grande
# Processing Record 42 of Set 4 | sanliurfa
# Processing Record 43 of Set 4 | bilibino
# Processing Record 44 of Set 4 | loango
# Processing Record 45 of Set 4 | kerch
# Processing Record 46 of Set 4 | tambura
# Processing Record 47 of Set 4 | taksimo
# Processing Record 48 of Set 4 | san luis
# Processing Record 49 of Set 4 | pangoa
# Processing Record 0 of Set 5 | knoxville
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | zaragoza
# Processing Record 3 of Set 5 | changping
# Processing Record 4 of Set 5 | kerikeri
# Processing Record 5 of Set 5 | toliara
# Processing Record 6 of Set 5 | taradale
# Processing Record 7 of Set 5 | korkut
# Processing Record 8 of Set 5 | cidreira
# Processing Record 9 of Set 5 | christchurch
# Processing Record 10 of Set 5 | dubrovnik
# Processing Record 11 of Set 5 | prineville
# Processing Record 12 of Set 5 | nantucket
# Processing Record 13 of Set 5 | tapes
# Processing Record 14 of Set 5 | kone
# Processing Record 15 of Set 5 | devarkonda
# Processing Record 16 of Set 5 | saint-joseph
# Processing Record 17 of Set 5 | berdigestyakh
# Processing Record 18 of Set 5 | calama
# Processing Record 19 of Set 5 | huarmey
# Processing Record 20 of Set 5 | yuzhno-kurilsk
# Processing Record 21 of Set 5 | daru
# Processing Record 22 of Set 5 | tarauaca
# Processing Record 23 of Set 5 | muisne
# Processing Record 24 of Set 5 | kapuskasing
# Processing Record 25 of Set 5 | sola
# Processing Record 26 of Set 5 | luanda
# Processing Record 27 of Set 5 | ieper
# Processing Record 28 of Set 5 | fort st. john
# Processing Record 29 of Set 5 | moroni
# Processing Record 30 of Set 5 | eyl
# Processing Record 31 of Set 5 | vilyuchinsk
# Processing Record 32 of Set 5 | ciudad lazaro cardenas
# Processing Record 33 of Set 5 | port hedland
# Processing Record 34 of Set 5 | ijuw
# City not found. Skipping...
# Processing Record 35 of Set 5 | pobugskoye
# Processing Record 36 of Set 5 | qaqortoq
# Processing Record 37 of Set 5 | lexington
# Processing Record 38 of Set 5 | najaf
# Processing Record 39 of Set 5 | bengkulu
# Processing Record 40 of Set 5 | al kharijah
# Processing Record 41 of Set 5 | we
# City not found. Skipping...
# Processing Record 42 of Set 5 | smolensk
# Processing Record 43 of Set 5 | axim
# Processing Record 44 of Set 5 | hawaiian paradise park
# Processing Record 45 of Set 5 | antonio enes
# Processing Record 46 of Set 5 | ad-damazin
# Processing Record 47 of Set 5 | moyale
# Processing Record 48 of Set 5 | kununurra
# Processing Record 49 of Set 5 | lauro de freitas
# Processing Record 0 of Set 6 | papao
# Processing Record 1 of Set 6 | vila franca do campo
# Processing Record 2 of Set 6 | callao
# Processing Record 3 of Set 6 | ribeira brava
# Processing Record 4 of Set 6 | malango
# Processing Record 5 of Set 6 | torghay
# Processing Record 6 of Set 6 | camana
# Processing Record 7 of Set 6 | saudarkrokur
# Processing Record 8 of Set 6 | vernon
# Processing Record 9 of Set 6 | rio pardo
# Processing Record 10 of Set 6 | quellon
# Processing Record 11 of Set 6 | sinor
# Processing Record 12 of Set 6 | karagandy
# Processing Record 13 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 14 of Set 6 | calvinia
# Processing Record 15 of Set 6 | aasiaat
# Processing Record 16 of Set 6 | sindhnur
# Processing Record 17 of Set 6 | ferkessedougou
# Processing Record 18 of Set 6 | cotonou
# Processing Record 19 of Set 6 | fauske
# Processing Record 20 of Set 6 | chibougamau
# Processing Record 21 of Set 6 | kodiak
# Processing Record 22 of Set 6 | kodinsk
# Processing Record 23 of Set 6 | manismata
# Processing Record 24 of Set 6 | oum hadjer
# Processing Record 25 of Set 6 | alvear
# Processing Record 26 of Set 6 | ranot
# Processing Record 27 of Set 6 | constitucion
# Processing Record 28 of Set 6 | nambucca heads
# Processing Record 29 of Set 6 | lompoc
# Processing Record 30 of Set 6 | bubaque
# Processing Record 31 of Set 6 | tralee
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | noosa heads
# Processing Record 34 of Set 6 | mangai
# Processing Record 35 of Set 6 | badger
# Processing Record 36 of Set 6 | koulikoro
# Processing Record 37 of Set 6 | zaozersk
# Processing Record 38 of Set 6 | yasnyy
# Processing Record 39 of Set 6 | santa cruz
# Processing Record 40 of Set 6 | apt
# Processing Record 41 of Set 6 | togur
# Processing Record 42 of Set 6 | bamboo flat
# Processing Record 43 of Set 6 | altai
# Processing Record 44 of Set 6 | drayton valley
# Processing Record 45 of Set 6 | chernyshevskiy
# Processing Record 46 of Set 6 | fiuggi
# Processing Record 47 of Set 6 | st. john's
# Processing Record 48 of Set 6 | levuka
# Processing Record 49 of Set 6 | eastbourne
# Processing Record 0 of Set 7 | kawthoung
# City not found. Skipping...
# Processing Record 1 of Set 7 | brisas de zicatela
# Processing Record 2 of Set 7 | kibworth harcourt
# Processing Record 3 of Set 7 | lulea
# Processing Record 4 of Set 7 | khandyga
# Processing Record 5 of Set 7 | codrington
# Processing Record 6 of Set 7 | south grafton
# Processing Record 7 of Set 7 | lerik
# Processing Record 8 of Set 7 | punta del este
# Processing Record 9 of Set 7 | nagqu
# Processing Record 10 of Set 7 | paredon
# Processing Record 11 of Set 7 | beichengqu
# Processing Record 12 of Set 7 | atafu village
# Processing Record 13 of Set 7 | opuwo
# Processing Record 14 of Set 7 | east ballina
# Processing Record 15 of Set 7 | coremas
# Processing Record 16 of Set 7 | coyhaique
# Processing Record 17 of Set 7 | waimea
# Processing Record 18 of Set 7 | port hueneme
# Processing Record 19 of Set 7 | nanping
# Processing Record 20 of Set 7 | tukzar
# Processing Record 21 of Set 7 | bondoukou
# Processing Record 22 of Set 7 | karasu
# Processing Record 23 of Set 7 | kletnya
# Processing Record 24 of Set 7 | mukalla
# Processing Record 25 of Set 7 | gisborne
# Processing Record 26 of Set 7 | holualoa
# Processing Record 27 of Set 7 | porto novo
# Processing Record 28 of Set 7 | kauit
# Processing Record 29 of Set 7 | colonia
# Processing Record 30 of Set 7 | colonia menno
# Processing Record 31 of Set 7 | nar'yan-mar
# Processing Record 32 of Set 7 | brookings
# Processing Record 33 of Set 7 | magadan
# Processing Record 34 of Set 7 | borogontsy
# Processing Record 35 of Set 7 | puerto aysen
# Processing Record 36 of Set 7 | rabaul
# Processing Record 37 of Set 7 | yarmouth
# Processing Record 38 of Set 7 | inongo
# Processing Record 39 of Set 7 | illizi
# Processing Record 40 of Set 7 | uturoa
# Processing Record 41 of Set 7 | coquimbo
# Processing Record 42 of Set 7 | nsanje
# Processing Record 43 of Set 7 | fortuna
# Processing Record 44 of Set 7 | port alfred
# Processing Record 45 of Set 7 | kavaratti
# Processing Record 46 of Set 7 | shwebo
# Processing Record 47 of Set 7 | prince rupert
# Processing Record 48 of Set 7 | mesolongi
# Processing Record 49 of Set 7 | ipora
# Processing Record 0 of Set 8 | ilhabela
# Processing Record 1 of Set 8 | pyay
# Processing Record 2 of Set 8 | santiago de cao
# Processing Record 3 of Set 8 | novyy urengoy
# Processing Record 4 of Set 8 | sisimiut
# Processing Record 5 of Set 8 | argo
# Processing Record 6 of Set 8 | haiku-pauwela
# Processing Record 7 of Set 8 | crane
# Processing Record 8 of Set 8 | tazovsky
# Processing Record 9 of Set 8 | pante makasar
# City not found. Skipping...
# Processing Record 10 of Set 8 | inari
# Processing Record 11 of Set 8 | barreirinhas
# Processing Record 12 of Set 8 | whitehorse
# Processing Record 13 of Set 8 | kenai
# Processing Record 14 of Set 8 | paraparaumu
# Processing Record 15 of Set 8 | muli
# Processing Record 16 of Set 8 | nizhneudinsk
# Processing Record 17 of Set 8 | basco
# Processing Record 18 of Set 8 | chervyen'
# Processing Record 19 of Set 8 | sinabang
# Processing Record 20 of Set 8 | tianshui
# Processing Record 21 of Set 8 | brigantine
# Processing Record 22 of Set 8 | urengoy
# Processing Record 23 of Set 8 | whistler
# Processing Record 24 of Set 8 | banjarmasin
# Processing Record 25 of Set 8 | ketchikan
# Processing Record 26 of Set 8 | yaren
# Processing Record 27 of Set 8 | rikaze
# Processing Record 28 of Set 8 | bol'shoye murashkino
# Processing Record 29 of Set 8 | kourou
# Processing Record 30 of Set 8 | alzamay
# Processing Record 31 of Set 8 | la passe
# Processing Record 32 of Set 8 | as sulayyil
# Processing Record 33 of Set 8 | erenhot
# Processing Record 34 of Set 8 | antsiranana
# Processing Record 35 of Set 8 | jutai
# Processing Record 36 of Set 8 | freeport
# Processing Record 37 of Set 8 | rongelap
# Processing Record 38 of Set 8 | kaspiyskiy
# Processing Record 39 of Set 8 | valparaiso
# Processing Record 40 of Set 8 | port augusta
# Processing Record 41 of Set 8 | lihue
# Processing Record 42 of Set 8 | prakhon chai
# Processing Record 43 of Set 8 | hadibu
# Processing Record 44 of Set 8 | tobi village
# City not found. Skipping...
# Processing Record 45 of Set 8 | santa terezinha
# Processing Record 46 of Set 8 | neyriz
# Processing Record 47 of Set 8 | susuman
# Processing Record 48 of Set 8 | sojat
# Processing Record 49 of Set 8 | west end
# Processing Record 0 of Set 9 | paracho de verduzco
# Processing Record 1 of Set 9 | rapid valley
# Processing Record 2 of Set 9 | turpan
# Processing Record 3 of Set 9 | geneina
# Processing Record 4 of Set 9 | baiti
# Processing Record 5 of Set 9 | acu
# Processing Record 6 of Set 9 | puerto baquerizo moreno
# Processing Record 7 of Set 9 | andovoranto
# Processing Record 8 of Set 9 | yalikavak
# City not found. Skipping...
# Processing Record 9 of Set 9 | buka
# Processing Record 10 of Set 9 | lycksele
# Processing Record 11 of Set 9 | sines
# Processing Record 12 of Set 9 | benavente
# Processing Record 13 of Set 9 | sittwe
# Processing Record 14 of Set 9 | kavieng
# Processing Record 15 of Set 9 | alice springs
# Processing Record 16 of Set 9 | puerto leguizamo
# Processing Record 17 of Set 9 | al ghayzah
# Processing Record 18 of Set 9 | shahganj
# Processing Record 19 of Set 9 | kristiansund
# Processing Record 20 of Set 9 | sonsorol village
# City not found. Skipping...
# Processing Record 21 of Set 9 | chul'man
# Processing Record 22 of Set 9 | keflavik
# Processing Record 23 of Set 9 | kendari
# Processing Record 24 of Set 9 | ulladulla
# Processing Record 25 of Set 9 | ghat
# Processing Record 26 of Set 9 | lido di ostia
# Processing Record 27 of Set 9 | lichinga
# Processing Record 28 of Set 9 | yazman
# Processing Record 29 of Set 9 | ribas do rio pardo
# Processing Record 30 of Set 9 | wolsztyn
# Processing Record 31 of Set 9 | bayan nur
# City not found. Skipping...
# Processing Record 32 of Set 9 | montrose
# Processing Record 33 of Set 9 | nova sintra
# Processing Record 34 of Set 9 | goshaingaon
# Processing Record 35 of Set 9 | neiafu
# Processing Record 36 of Set 9 | rugaji
# Processing Record 37 of Set 9 | beinamar
# Processing Record 38 of Set 9 | yangor
# City not found. Skipping...
# Processing Record 39 of Set 9 | isangel
# Processing Record 40 of Set 9 | ati
# Processing Record 41 of Set 9 | tahe
# Processing Record 42 of Set 9 | sawang daen din
# Processing Record 43 of Set 9 | manta
# Processing Record 44 of Set 9 | merida
# Processing Record 45 of Set 9 | thunder bay
# Processing Record 46 of Set 9 | bayanaul
# Processing Record 47 of Set 9 | saint-pierre
# Processing Record 48 of Set 9 | remire-montjoly
# Processing Record 49 of Set 9 | miracema do tocantins
# Processing Record 0 of Set 10 | pyt-yakh
# Processing Record 1 of Set 10 | i-n-salah
# Processing Record 2 of Set 10 | shirgaon
# Processing Record 3 of Set 10 | singkil
# Processing Record 4 of Set 10 | klyuchi
# Processing Record 5 of Set 10 | shibetsu
# Processing Record 6 of Set 10 | kalmunai
# Processing Record 7 of Set 10 | asenovgrad
# Processing Record 8 of Set 10 | jean-rabel
# Processing Record 9 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 10 of Set 10 | kittila
# Processing Record 11 of Set 10 | paracuru
# Processing Record 12 of Set 10 | nadym
# Processing Record 13 of Set 10 | preobrazheniye
# Processing Record 14 of Set 10 | barra
# Processing Record 15 of Set 10 | sept-iles
# Processing Record 16 of Set 10 | el dorado
# Processing Record 17 of Set 10 | nogliki
# Processing Record 18 of Set 10 | aitape
# Processing Record 19 of Set 10 | karacoban
# Processing Record 20 of Set 10 | ploneour-lanvern
# Processing Record 21 of Set 10 | kodok
# City not found. Skipping...
# Processing Record 22 of Set 10 | antofagasta
# Processing Record 23 of Set 10 | bardai
# Processing Record 24 of Set 10 | harrisburg
# Processing Record 25 of Set 10 | bathsheba
# Processing Record 26 of Set 10 | homestead meadows north
# Processing Record 27 of Set 10 | frontera
# Processing Record 28 of Set 10 | akureyri
# Processing Record 29 of Set 10 | margate
# Processing Record 30 of Set 10 | auna
# Processing Record 31 of Set 10 | red hill
# Processing Record 32 of Set 10 | hilo
# Processing Record 33 of Set 10 | piggs peak
# Processing Record 34 of Set 10 | port saint john's
# Processing Record 35 of Set 10 | santo antonio do sudoeste
# Processing Record 36 of Set 10 | tamanrasset
# Processing Record 37 of Set 10 | milas
# Processing Record 38 of Set 10 | marsh harbour
# Processing Record 39 of Set 10 | utete
# Processing Record 40 of Set 10 | benjamin constant
# Processing Record 41 of Set 10 | port lincoln
# Processing Record 42 of Set 10 | veymandoo
# City not found. Skipping...
# Processing Record 43 of Set 10 | tulun
# Processing Record 44 of Set 10 | dryden
# Processing Record 45 of Set 10 | mejit
# Processing Record 46 of Set 10 | larache
# Processing Record 47 of Set 10 | eureka
# Processing Record 48 of Set 10 | kujama
# Processing Record 49 of Set 10 | urubamba
# Processing Record 0 of Set 11 | arkhangel'sk
# Processing Record 1 of Set 11 | hami
# Processing Record 2 of Set 11 | saint-tropez
# Processing Record 3 of Set 11 | howard springs
# Processing Record 4 of Set 11 | acarau
# Processing Record 5 of Set 11 | yilan
# Processing Record 6 of Set 11 | baley
# Processing Record 7 of Set 11 | nizhniy odes
# Processing Record 8 of Set 11 | narva
# Processing Record 9 of Set 11 | tejen
# Processing Record 10 of Set 11 | tanumah
# Processing Record 11 of Set 11 | walvis bay
# Processing Record 12 of Set 11 | xilin hot
# Processing Record 13 of Set 11 | sumbe
# Processing Record 14 of Set 11 | okhotsk
# Processing Record 15 of Set 11 | busselton
# Processing Record 16 of Set 11 | peace river
# Processing Record 17 of Set 11 | lerwick
# Processing Record 18 of Set 11 | luderitz
# Processing Record 19 of Set 11 | alta sierra
# Processing Record 20 of Set 11 | ladismith
# City not found. Skipping...
# Processing Record 21 of Set 11 | tierralta
# Processing Record 22 of Set 11 | shakawe
# Processing Record 23 of Set 11 | klaksvik
# Processing Record 24 of Set 11 | carbonear
# Processing Record 25 of Set 11 | nadi
# Processing Record 26 of Set 11 | vorkuta
# Processing Record 27 of Set 11 | puerto armuelles
# Processing Record 28 of Set 11 | talakan
# Processing Record 29 of Set 11 | zhangatas
# Processing Record 30 of Set 11 | al 'alamayn
# City not found. Skipping...
# Processing Record 31 of Set 11 | abong mbang
# Processing Record 32 of Set 11 | metu
# Processing Record 33 of Set 11 | sabang
# Processing Record 34 of Set 11 | tidjikja
# Processing Record 35 of Set 11 | homer
# Processing Record 36 of Set 11 | namibe
# Processing Record 37 of Set 11 | xiva
# Processing Record 38 of Set 11 | sakete
# Processing Record 39 of Set 11 | the bottom
# Processing Record 40 of Set 11 | shimoda
# Processing Record 41 of Set 11 | sanming
# Processing Record 42 of Set 11 | yeola
# Processing Record 43 of Set 11 | eibergen
# Processing Record 44 of Set 11 | sulak
# Processing Record 45 of Set 11 | ormara
# Processing Record 46 of Set 11 | puerto princesa
# Processing Record 47 of Set 11 | kingston
# Processing Record 48 of Set 11 | nemuro
# Processing Record 49 of Set 11 | nyurba
# Processing Record 0 of Set 12 | l'escala
# Processing Record 1 of Set 12 | ibiruba
# Processing Record 2 of Set 12 | olivet
# Processing Record 3 of Set 12 | port isabel
# Processing Record 4 of Set 12 | cargados carajos
# City not found. Skipping...
# Processing Record 5 of Set 12 | elmendorf air force base
# City not found. Skipping...
# Processing Record 6 of Set 12 | talara
# Processing Record 7 of Set 12 | zouerate
# Processing Record 8 of Set 12 | cockburn town
# Processing Record 9 of Set 12 | mata-utu
# Processing Record 10 of Set 12 | charlestown
# Processing Record 11 of Set 12 | acapulco de juarez
# Processing Record 12 of Set 12 | al jubayl
# Processing Record 13 of Set 12 | usinsk
# Processing Record 14 of Set 12 | sishilichengzi
# City not found. Skipping...
# Processing Record 15 of Set 12 | barra de santo antonio
# Processing Record 16 of Set 12 | vila velha
# Processing Record 17 of Set 12 | monte carmelo
# Processing Record 18 of Set 12 | lata
# Processing Record 19 of Set 12 | severo-yeniseyskiy
# Processing Record 20 of Set 12 | harrison
# Processing Record 21 of Set 12 | padang
# Processing Record 22 of Set 12 | kidal
# Processing Record 23 of Set 12 | vize
# Processing Record 24 of Set 12 | labytnangi
# Processing Record 25 of Set 12 | nicoya
# Processing Record 26 of Set 12 | strezhevoy
# Processing Record 27 of Set 12 | akobo
# Processing Record 28 of Set 12 | dolgorukovo
# Processing Record 29 of Set 12 | cascais
# Processing Record 30 of Set 12 | myanaung
# Processing Record 31 of Set 12 | maintirano
# Processing Record 32 of Set 12 | krasnopillya
# Processing Record 33 of Set 12 | dogondoutchi
# Processing Record 34 of Set 12 | salamanca
# Processing Record 35 of Set 12 | ruiz
# Processing Record 36 of Set 12 | lubao
# Processing Record 37 of Set 12 | knyaze-volkonskoye
# Processing Record 38 of Set 12 | yichun
# Processing Record 39 of Set 12 | burao
# Processing Record 40 of Set 12 | lewistown
# Processing Record 41 of Set 12 | murom
# Processing Record 42 of Set 12 | rokytne
# Processing Record 43 of Set 12 | nelson bay
# Processing Record 44 of Set 12 | moranbah
# Processing Record 45 of Set 12 | rakops
# Processing Record 46 of Set 12 | villa gesell
# Processing Record 47 of Set 12 | kanggye
# Processing Record 48 of Set 12 | joao pinheiro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame({"City": city_name, 
                          "Lat": city_lat, 
                          "Lng": city_lon, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Natales -51.7236  -72.4875     38.25        95         100
# 1    Marsá Maţrūḩ  31.3525   27.2453     80.94        62           0
# 2        Vilyuysk  63.7553  121.6247     61.16        63           0
# 3     Curitibanos -27.2828  -50.5844     64.20        87          91
# 4         Zuyevka  58.4050   51.1335     67.86        72           2
#
#    Wind Speed Country        Date
# 0        5.61      CL  1691688024
# 1       12.84      EG  1691688581
# 2        7.94      RU  1691688099
# 3        3.58      BR  1691688581
# 4        4.65      RU  1691688581

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        Puerto Natales -51.7236  -72.4875     38.25        95         100
# 1          Marsá Maţrūḩ  31.3525   27.2453     80.94        62           0
# 2              Vilyuysk  63.7553  121.6247     61.16        63           0
# 3           Curitibanos -27.2828  -50.5844     64.20        87          91
# 4               Zuyevka  58.4050   51.1335     67.86        72           2
#
#          Wind Speed Country        Date
# City_ID
# 0              5.61      CL  1691688024
# 1             12.84      EG  1691688581
# 2              7.94      RU  1691688099
# 3              3.58      BR  1691688581
# 4              4.65      RU  1691688581

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_lat,city_max_temp, marker="o", color="blue")
plt.title("City Max Latitude vs Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

plt.show()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_lat,city_humidity, marker="o", color="blue")
plt.title("City Max Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity)")

plt.show()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_lat,city_clouds, marker="o", color="blue")
plt.title("Cit Max Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.show()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_lat,city_wind, marker="o", color="blue")
plt.title("Cit Max Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.show()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Perform a linear regression
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
    regress_values = x_values * slope + intercept

# Define a function to create Linear Regression plots
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        Marsá Maţrūḩ  31.3525   27.2453     80.94        62           0
# 2            Vilyuysk  63.7553  121.6247     61.16        63           0
# 4             Zuyevka  58.4050   51.1335     67.86        72           2
# 5           Vorgashor  67.5833   63.9500     49.28        85          23
# 6             Sibolga   1.7427   98.7792     76.51        90         100
#
#          Wind Speed Country        Date
# City_ID
# 1             12.84      EG  1691688581
# 2              7.94      RU  1691688099
# 4              4.65      RU  1691688581
# 5              8.77      RU  1691688041
# 6              3.53      ID  1691688581

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        Puerto Natales -51.7236  -72.4875     38.25        95         100
# 3           Curitibanos -27.2828  -50.5844     64.20        87          91
# 7             Grytviken -54.2811  -36.5092     26.08        95          95
# 10         Puerto Ayora  -0.7393  -90.3518     82.36        98          80
# 11            Adamstown -25.0660 -130.1015     64.89        62          65
#
#          Wind Speed Country        Date
# City_ID
# 0              5.61      CL  1691688024
# 3              3.58      BR  1691688581
# 7              7.65      GS  1691688026
# 10             5.99      EC  1691687979
# 11            24.05      PN  1691688027

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]


plot_linear_regression(x_values, y_values, "Temperature vs Latitude","Max Temp", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.65

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]


plot_linear_regression(x_values, y_values, "Temperature vs Latitude","Max Temp", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is 0.8

# %% [markdown]
# **Discussion about the linear relationship:** <br>
# In the northern hemisphere, there is a negative correlation between latitude and temperature. If you are father away from the equator, the temperature will be colder.
# In the southern hemisphere, there is a positivte correlation between latitude and temperature. Locations along the equator have higher temperatures.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]


plot_linear_regression(x_values, y_values, "Latitude vs Humidity","Humidity", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is 0.03

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]


plot_linear_regression(x_values, y_values, "Latitude vs Humidity","Humidity", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.2

# %% [markdown]
# **Discussion about the linear relationship:** <br>
# The analysis suggests that there is not much of a relationship between humidity and latitude in both northern and southern hemispheres. The values do not follow much of a pattern.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]


plot_linear_regression(x_values, y_values, "Cloudiness vs Latitude","Cloudiness", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.13

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]


plot_linear_regression(x_values, y_values, "Cloudiness vs Latitude","Cloudiness", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.17

# %% [markdown]
# **Discussion about the linear relationship:** <br>
# The analysis suggests that there is not much of a relationship between cloudiness and latitude in both northern and southern hemispheres. Cloudiess is affected by differt factors such as precipitation and temperature.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]


plot_linear_regression(x_values, y_values, "Wind Speed vs Latitude","Wind Speed", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is -0.06

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]


plot_linear_regression(x_values, y_values, "Wind Speed vs Latitude","Wind Speed", (10,30))

correlation = st.pearsonr(x_values, y_values)
print(f"The correlation is {round(correlation[0],2)}")
# Out:
# The correlation is 0.01

# %% [markdown]
# **Discussion about the linear relationship:** <br>
# In both northern and southern hemispheres, there is a concentration of data points at lower wind speeds across all latitudes. Although this can be observed, there is still not a correlations between latitude and wind speed.
